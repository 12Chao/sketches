# %%
import yaml

# %%
with open("n_heptane/n_heptane_annotated.yaml", 'r') as f:
    model = yaml.load(f, Loader=yaml.FullLoader)

# %%
H_abs = []
for r in model['reactions']:
    if 'H_Abstraction' in r['note'].split():
        H_abs.append(r['equation'])

# %%
model['units']
# Out:
# {'length': 'cm',
#  'time': 's',
#  'quantity': 'mol',
#  'activation-energy': 'kcal/mol'}

# %%
# Create a Blowers-Masel reaction list
bm_rxns = []
for rxn in H_abs:
    for i in range(len(model['reactions'])):
        if rxn == model['reactions'][i]['equation']:
            rc = model['reactions'][i]['rate-constant']
            rc['Ea0'] = rc['Ea']
            rc['w'] = 239.0
            bm_rxns.append(model['reactions'][i])

# %%
for rxn in bm_rxns:
    del rxn['rate-constant']['Ea']

# %%
bm_rxns
# Out:
# [{'equation': 'HO2(17) + CH2(24) <=> O2(2) + CH3(19)',
#   'rate-constant': {'A': 129807800.0, 'b': 0.805, 'Ea0': 1.37, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #732; RMG #3515\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); CH2(24), CH3(19);\nEstimated using average of templates [X_H;CH2_triplet] + [Orad_O_H;Y_rad_birad_trirad_quadrad] for rate rule [Orad_O_H;CH2_triplet]\nEuclidian distance = 2.0\nfamily: H_Abstraction'},
#  {'equation': 'HO2(17) + C7H15(686) <=> O2(2) + C7H16(1)',
#   'rate-constant': {'A': 0.02759059, 'b': 3.802, 'Ea0': 6.324, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #868; RMG #3438\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); C7H15(686), C7H16(1);\nEstimated using template [X_H;C_rad/H/NonDeC] for rate rule [Orad_O_H;C_rad/H/NonDeC]\nEuclidian distance = 2.0\nfamily: H_Abstraction'},
#  {'equation': 'O(5) + C7H16(1) <=> OH(15) + C7H15(686)',
#   'rate-constant': {'A': 2218.692, 'b': 3.19, 'Ea0': 14.117, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #869; RMG #3442\nTemplate reaction: H_Abstraction\nFlux pairs: O(5), OH(15); C7H16(1), C7H15(686);\nEstimated using an average for rate rule [C/H2/NonDeC;O_atom_triplet]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'H(14) + C7H16(1) <=> H2(13) + C7H15(686)',
#   'rate-constant': {'A': 127.65, 'b': 3.68, 'Ea0': 4.7, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #870; RMG #3499\nTemplate reaction: H_Abstraction\nFlux pairs: H(14), H2(13); C7H16(1), C7H15(686);\nEstimated using an average for rate rule [C/H2/NonDeC;H_rad]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'OH(15) + C7H16(1) <=> H2O(8) + C7H15(686)',
#   'rate-constant': {'A': 28002300.0, 'b': 1.6, 'Ea0': 0.471, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #871; RMG #3503\nTemplate reaction: H_Abstraction\nFlux pairs: OH(15), H2O(8); C7H16(1), C7H15(686);\nFrom training reaction 3104 used for C/H2/NonDeC;O_pri_rad\nExact match found for rate rule [C/H2/NonDeC;O_pri_rad]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'H2O2(18) + C7H15(686) <=> HO2(17) + C7H16(1)',
#   'rate-constant': {'A': 0.002101105, 'b': 4.133, 'Ea0': 0.542, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #872; RMG #3508\nTemplate reaction: H_Abstraction\nFlux pairs: H2O2(18), HO2(17); C7H15(686), C7H16(1);\nEstimated using an average for rate rule [H2O2;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3(19) + C7H16(1) <=> CH4(10) + C7H15(686)',
#   'rate-constant': {'A': 0.03212, 'b': 4.34, 'Ea0': 6.61, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #873; RMG #3513\nTemplate reaction: H_Abstraction\nFlux pairs: CH3(19), CH4(10); C7H16(1), C7H15(686);\nEstimated using an average for rate rule [C/H2/NonDeC;C_methyl]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3OOH(36) + C7H15(686) <=> CH3OO(33) + C7H16(1)',
#   'rate-constant': {'A': 6.648107e-06, 'b': 4.906, 'Ea0': -2.464, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #874; RMG #3518\nTemplate reaction: H_Abstraction\nFlux pairs: CH3OOH(36), CH3OO(33); C7H15(686), C7H16(1);\nEstimated using an average for rate rule [O/H/NonDeO;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction'},
#  {'equation': 'C2H5(34) + C7H16(1) <=> C2H6(38) + C7H15(686)',
#   'rate-constant': {'A': 0.004327734, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #875; RMG #3524\nTemplate reaction: H_Abstraction\nFlux pairs: C2H5(34), C2H6(38); C7H16(1), C7H15(686);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H2/Cs\\H3]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H6O2(62) + C7H15(686) <=> C2H5O2(41) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #878; RMG #3539\nTemplate reaction: H_Abstraction\nFlux pairs: C2H6O2(62), C2H5O2(41); C7H15(686), C7H16(1);\nEstimated using an average for rate rule [ROOH_pri;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'O2(2) + CH3OOH(36) <=> HO2(17) + CH2OOH(37)',
#   'rate-constant': {'A': 360000.0, 'b': 2.27, 'Ea0': 49.297, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #884; RMG #4253\nTemplate reaction: H_Abstraction\nFlux pairs: O2(2), HO2(17); CH3OOH(36), CH2OOH(37);\nFrom training reaction 199 used for C/H3/O;O2b\nExact match found for rate rule [C/H3/O;O2b]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 6.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H5O(40) + C7H16(1) <=> C2H6O(55) + C7H15(686)',
#   'rate-constant': {'A': 220000000000.0, 'b': 0.0, 'Ea0': 8.624, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #885; RMG #4256\nTemplate reaction: H_Abstraction\nFlux pairs: C2H5O(40), C2H6O(55); C7H16(1), C7H15(686);\nEstimated using an average for rate rule [C/H2/NonDeC;O_rad/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'HO2(17) + C2H5O2(63) <=> O2(2) + C2H6O2(62)',
#   'rate-constant': {'A': 0.002641929, 'b': 4.194, 'Ea0': 2.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #886; RMG #4260\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); C2H5O2(63), C2H6O2(62);\nEstimated using template [X_H;C_rad/H/CsO] for rate rule [Orad_O_H;C_rad/H/CsO]\nEuclidian distance = 2.0\nfamily: H_Abstraction'},
#  {'equation': 'HO2(17) + C2H5O2(46) <=> O2(2) + C2H6O2(62)',
#   'rate-constant': {'A': 3.062323, 'b': 3.295, 'Ea0': 9.354, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #887; RMG #4261\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); C2H5O2(46), C2H6O2(62);\nEstimated using template [X_H;C_rad/H2/Cs] for rate rule [Orad_O_H;C_rad/H2/Cs]\nEuclidian distance = 2.0\nfamily: H_Abstraction'},
#  {'equation': 'HO2(17) + C7H15(683) <=> O2(2) + C7H16(1)',
#   'rate-constant': {'A': 0.02759059, 'b': 3.802, 'Ea0': 6.324, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #914; RMG #3436\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); C7H15(683), C7H16(1);\nEstimated using template [X_H;C_rad/H/NonDeC] for rate rule [Orad_O_H;C_rad/H/NonDeC]\nEuclidian distance = 2.0\nfamily: H_Abstraction'},
#  {'equation': 'O(5) + C7H16(1) <=> OH(15) + C7H15(683)',
#   'rate-constant': {'A': 2218.692, 'b': 3.19, 'Ea0': 14.117, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #915; RMG #3440\nTemplate reaction: H_Abstraction\nFlux pairs: O(5), OH(15); C7H16(1), C7H15(683);\nEstimated using an average for rate rule [C/H2/NonDeC;O_atom_triplet]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'H(14) + C7H16(1) <=> H2(13) + C7H15(683)',
#   'rate-constant': {'A': 127.65, 'b': 3.68, 'Ea0': 4.7, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #916; RMG #3497\nTemplate reaction: H_Abstraction\nFlux pairs: H(14), H2(13); C7H16(1), C7H15(683);\nEstimated using an average for rate rule [C/H2/NonDeC;H_rad]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'OH(15) + C7H16(1) <=> H2O(8) + C7H15(683)',
#   'rate-constant': {'A': 28002300.0, 'b': 1.6, 'Ea0': 0.471, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #917; RMG #3501\nTemplate reaction: H_Abstraction\nFlux pairs: OH(15), H2O(8); C7H16(1), C7H15(683);\nFrom training reaction 3104 used for C/H2/NonDeC;O_pri_rad\nExact match found for rate rule [C/H2/NonDeC;O_pri_rad]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'H2O2(18) + C7H15(683) <=> HO2(17) + C7H16(1)',
#   'rate-constant': {'A': 0.002101105, 'b': 4.133, 'Ea0': 0.542, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #918; RMG #3506\nTemplate reaction: H_Abstraction\nFlux pairs: H2O2(18), HO2(17); C7H15(683), C7H16(1);\nEstimated using an average for rate rule [H2O2;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3(19) + C7H16(1) <=> CH4(10) + C7H15(683)',
#   'rate-constant': {'A': 0.03212, 'b': 4.34, 'Ea0': 6.61, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #919; RMG #3511\nTemplate reaction: H_Abstraction\nFlux pairs: CH3(19), CH4(10); C7H16(1), C7H15(683);\nEstimated using an average for rate rule [C/H2/NonDeC;C_methyl]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3OOH(36) + C7H15(683) <=> CH3OO(33) + C7H16(1)',
#   'rate-constant': {'A': 6.648107e-06, 'b': 4.906, 'Ea0': -2.464, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #920; RMG #3516\nTemplate reaction: H_Abstraction\nFlux pairs: CH3OOH(36), CH3OO(33); C7H15(683), C7H16(1);\nEstimated using an average for rate rule [O/H/NonDeO;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction'},
#  {'equation': 'C2H5(34) + C7H16(1) <=> C2H6(38) + C7H15(683)',
#   'rate-constant': {'A': 0.004327734, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #921; RMG #3522\nTemplate reaction: H_Abstraction\nFlux pairs: C2H5(34), C2H6(38); C7H16(1), C7H15(683);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H2/Cs\\H3]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H6O2(62) + C7H15(683) <=> C2H5O2(41) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #924; RMG #3537\nTemplate reaction: H_Abstraction\nFlux pairs: C2H6O2(62), C2H5O2(41); C7H15(683), C7H16(1);\nEstimated using an average for rate rule [ROOH_pri;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'C2H5O(40) + C7H16(1) <=> C2H6O(55) + C7H15(683)',
#   'rate-constant': {'A': 220000000000.0, 'b': 0.0, 'Ea0': 8.624, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #931; RMG #4254\nTemplate reaction: H_Abstraction\nFlux pairs: C2H5O(40), C2H6O(55); C7H16(1), C7H15(683);\nEstimated using an average for rate rule [C/H2/NonDeC;O_rad/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(683) + C7H16(1) <=> C7H15(686) + C7H16(1)',
#   'rate-constant': {'A': 0.005147495, 'b': 4.29, 'Ea0': 7.713, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #932; RMG #4266\nTemplate reaction: H_Abstraction\nFlux pairs: C7H16(1), C7H15(686); C7H15(683), C7H16(1);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3O(31) + C7H16(1) <=> CH3OH(28) + C7H15(683)',
#   'rate-constant': {'A': 220000000000.0, 'b': 0.0, 'Ea0': 8.624, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #936; RMG #4506\nTemplate reaction: H_Abstraction\nFlux pairs: CH3O(31), CH3OH(28); C7H16(1), C7H15(683);\nEstimated using an average for rate rule [C/H2/NonDeC;O_rad/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3O(31) + C7H16(1) <=> CH3OH(28) + C7H15(686)',
#   'rate-constant': {'A': 220000000000.0, 'b': 0.0, 'Ea0': 8.624, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #937; RMG #4508\nTemplate reaction: H_Abstraction\nFlux pairs: CH3O(31), CH3OH(28); C7H16(1), C7H15(686);\nEstimated using an average for rate rule [C/H2/NonDeC;O_rad/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'O2(2) + C2H4O(43) <=> HO2(17) + CHCHOH(52)',
#   'rate-constant': {'A': 35500000000000.0,
#    'b': 0.0,
#    'Ea0': 65.008,
#    'w': 239.0},
#   'note': 'Reaction index: Chemkin #938; RMG #4512\nTemplate reaction: H_Abstraction\nFlux pairs: O2(2), HO2(17); C2H4O(43), CHCHOH(52);\nFrom training reaction 219 used for Cd/H2/NonDeC;O2b\nExact match found for rate rule [Cd/H2/NonDeC;O2b]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'HO2(17) + C2H5O(40) <=> O2(2) + C2H6O(55)',
#   'rate-constant': {'A': 140000000000.0, 'b': 0.0, 'Ea0': 0.0, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #939; RMG #4515\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); C2H5O(40), C2H6O(55);\nFrom training reaction 200 used for Orad_O_H;O_rad/NonDeC\nExact match found for rate rule [Orad_O_H;O_rad/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction'},
#  {'equation': 'HO2(17) + C7H15(684) <=> O2(2) + C7H16(1)',
#   'rate-constant': {'A': 0.02759059, 'b': 3.802, 'Ea0': 6.324, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #951; RMG #3437\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); C7H15(684), C7H16(1);\nEstimated using template [X_H;C_rad/H/NonDeC] for rate rule [Orad_O_H;C_rad/H/NonDeC]\nEuclidian distance = 2.0\nfamily: H_Abstraction'},
#  {'equation': 'O(5) + C7H16(1) <=> OH(15) + C7H15(684)',
#   'rate-constant': {'A': 1109.346, 'b': 3.19, 'Ea0': 14.117, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #952; RMG #3441\nTemplate reaction: H_Abstraction\nFlux pairs: O(5), OH(15); C7H16(1), C7H15(684);\nEstimated using an average for rate rule [C/H2/NonDeC;O_atom_triplet]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'H(14) + C7H16(1) <=> H2(13) + C7H15(684)',
#   'rate-constant': {'A': 63.825, 'b': 3.68, 'Ea0': 4.7, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #953; RMG #3498\nTemplate reaction: H_Abstraction\nFlux pairs: H(14), H2(13); C7H16(1), C7H15(684);\nEstimated using an average for rate rule [C/H2/NonDeC;H_rad]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'OH(15) + C7H16(1) <=> H2O(8) + C7H15(684)',
#   'rate-constant': {'A': 14001150.0, 'b': 1.6, 'Ea0': 0.471, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #954; RMG #3502\nTemplate reaction: H_Abstraction\nFlux pairs: OH(15), H2O(8); C7H16(1), C7H15(684);\nFrom training reaction 3104 used for C/H2/NonDeC;O_pri_rad\nExact match found for rate rule [C/H2/NonDeC;O_pri_rad]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'H2O2(18) + C7H15(684) <=> HO2(17) + C7H16(1)',
#   'rate-constant': {'A': 0.002101105, 'b': 4.133, 'Ea0': 0.542, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #955; RMG #3507\nTemplate reaction: H_Abstraction\nFlux pairs: H2O2(18), HO2(17); C7H15(684), C7H16(1);\nEstimated using an average for rate rule [H2O2;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3(19) + C7H16(1) <=> CH4(10) + C7H15(684)',
#   'rate-constant': {'A': 0.01606, 'b': 4.34, 'Ea0': 6.61, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #956; RMG #3512\nTemplate reaction: H_Abstraction\nFlux pairs: CH3(19), CH4(10); C7H16(1), C7H15(684);\nEstimated using an average for rate rule [C/H2/NonDeC;C_methyl]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3OOH(36) + C7H15(684) <=> CH3OO(33) + C7H16(1)',
#   'rate-constant': {'A': 6.648107e-06, 'b': 4.906, 'Ea0': -2.464, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #957; RMG #3517\nTemplate reaction: H_Abstraction\nFlux pairs: CH3OOH(36), CH3OO(33); C7H15(684), C7H16(1);\nEstimated using an average for rate rule [O/H/NonDeO;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction'},
#  {'equation': 'C2H5(34) + C7H16(1) <=> C2H6(38) + C7H15(684)',
#   'rate-constant': {'A': 0.002163867, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #958; RMG #3523\nTemplate reaction: H_Abstraction\nFlux pairs: C2H5(34), C2H6(38); C7H16(1), C7H15(684);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H2/Cs\\H3]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H6O2(62) + C7H15(684) <=> C2H5O2(41) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #961; RMG #3538\nTemplate reaction: H_Abstraction\nFlux pairs: C2H6O2(62), C2H5O2(41); C7H15(684), C7H16(1);\nEstimated using an average for rate rule [ROOH_pri;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'C2H5O(40) + C7H16(1) <=> C2H6O(55) + C7H15(684)',
#   'rate-constant': {'A': 110000000000.0, 'b': 0.0, 'Ea0': 8.624, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #967; RMG #4255\nTemplate reaction: H_Abstraction\nFlux pairs: C2H5O(40), C2H6O(55); C7H16(1), C7H15(684);\nEstimated using an average for rate rule [C/H2/NonDeC;O_rad/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(684) + C7H16(1) <=> C7H15(686) + C7H16(1)',
#   'rate-constant': {'A': 0.005147495, 'b': 4.29, 'Ea0': 7.713, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #968; RMG #4267\nTemplate reaction: H_Abstraction\nFlux pairs: C7H16(1), C7H15(686); C7H15(684), C7H16(1);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(684) + C7H16(1) <=> C7H15(683) + C7H16(1)',
#   'rate-constant': {'A': 0.005147495, 'b': 4.29, 'Ea0': 7.713, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #970; RMG #4452\nTemplate reaction: H_Abstraction\nFlux pairs: C7H16(1), C7H15(683); C7H15(684), C7H16(1);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3O(31) + C7H16(1) <=> CH3OH(28) + C7H15(684)',
#   'rate-constant': {'A': 110000000000.0, 'b': 0.0, 'Ea0': 8.624, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #971; RMG #4507\nTemplate reaction: H_Abstraction\nFlux pairs: CH3O(31), CH3OH(28); C7H16(1), C7H15(684);\nEstimated using an average for rate rule [C/H2/NonDeC;O_rad/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'HO2(17) + C7H15(687) <=> O2(2) + C7H16(1)',
#   'rate-constant': {'A': 3.062323, 'b': 3.295, 'Ea0': 9.354, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #979; RMG #3439\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); C7H15(687), C7H16(1);\nEstimated using template [X_H;C_rad/H2/Cs] for rate rule [Orad_O_H;C_rad/H2/Cs]\nEuclidian distance = 2.0\nfamily: H_Abstraction'},
#  {'equation': 'O(5) + C7H16(1) <=> OH(15) + C7H15(687)',
#   'rate-constant': {'A': 1940.0, 'b': 3.23, 'Ea0': 4.66, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #980; RMG #3443\nTemplate reaction: H_Abstraction\nFlux pairs: O(5), OH(15); C7H16(1), C7H15(687);\nEstimated using template [C/H3/Cs\\OneNonDe;O_atom_triplet] for rate rule [C/H3/Cs\\H2\\Cs;O_atom_triplet]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 6.0\nfamily: H_Abstraction'},
#  {'equation': 'H(14) + C7H16(1) <=> H2(13) + C7H15(687)',
#   'rate-constant': {'A': 16638.24, 'b': 2.718, 'Ea0': 6.496, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #981; RMG #3500\nTemplate reaction: H_Abstraction\nFlux pairs: H(14), H2(13); C7H16(1), C7H15(687);\nEstimated using average of templates [C/H3/Cs\\OneNonDe;H_rad] + [C/H3/Cs\\H2\\Cs;Y_rad] for rate rule [C/H3/Cs\\H2\\Cs;H_rad]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 6.0\nfamily: H_Abstraction'},
#  {'equation': 'OH(15) + C7H16(1) <=> H2O(8) + C7H15(687)',
#   'rate-constant': {'A': 18800.0, 'b': 2.67, 'Ea0': -1.004, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #982; RMG #3504\nTemplate reaction: H_Abstraction\nFlux pairs: OH(15), H2O(8); C7H16(1), C7H15(687);\nEstimated using template [C/H3/Cs\\OneNonDe;O_pri_rad] for rate rule [C/H3/Cs\\H2\\Cs;O_pri_rad]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 6.0\nfamily: H_Abstraction'},
#  {'equation': 'H2O2(18) + C7H15(687) <=> HO2(17) + C7H16(1)',
#   'rate-constant': {'A': 1.773899, 'b': 3.328, 'Ea0': 1.143, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #983; RMG #3509\nTemplate reaction: H_Abstraction\nFlux pairs: H2O2(18), HO2(17); C7H15(687), C7H16(1);\nEstimated using an average for rate rule [H2O2;C_rad/H2/Cs]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3(19) + C7H16(1) <=> CH4(10) + C7H15(687)',
#   'rate-constant': {'A': 4.0, 'b': 3.57, 'Ea0': 7.717, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #984; RMG #3514\nTemplate reaction: H_Abstraction\nFlux pairs: CH3(19), CH4(10); C7H16(1), C7H15(687);\nEstimated using template [C/H3/Cs\\OneNonDe;C_methyl] for rate rule [C/H3/Cs\\H2\\Cs;C_methyl]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 6.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3OOH(36) + C7H15(687) <=> CH3OO(33) + C7H16(1)',
#   'rate-constant': {'A': 0.0006391396, 'b': 4.352, 'Ea0': -1.737, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #985; RMG #3519\nTemplate reaction: H_Abstraction\nFlux pairs: CH3OOH(36), CH3OO(33); C7H15(687), C7H16(1);\nEstimated using an average for rate rule [O/H/NonDeO;C_rad/H2/Cs]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -7.3 to -7.3 kJ/mol.'},
#  {'equation': 'C2H5(34) + C7H16(1) <=> C2H6(38) + C7H15(687)',
#   'rate-constant': {'A': 0.00552, 'b': 4.34, 'Ea0': 9.2, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #986; RMG #3525\nTemplate reaction: H_Abstraction\nFlux pairs: C2H5(34), C2H6(38); C7H16(1), C7H15(687);\nEstimated using template [C/H3/Cs;C_rad/H2/Cs\\H3] for rate rule [C/H3/Cs\\H2\\Cs;C_rad/H2/Cs\\H3]\nEuclidian distance = 2.0\nMultiplied by reaction path degeneracy 6.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H6O2(62) + C7H15(687) <=> C2H5O2(41) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #989; RMG #3540\nTemplate reaction: H_Abstraction\nFlux pairs: C2H6O2(62), C2H5O2(41); C7H15(687), C7H16(1);\nEstimated using an average for rate rule [ROOH_pri;C_rad/H2/Cs]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'C2H5O(40) + C7H16(1) <=> C2H6O(55) + C7H15(687)',
#   'rate-constant': {'A': 24000.0, 'b': 2.55, 'Ea0': 15.75, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #996; RMG #4257\nTemplate reaction: H_Abstraction\nFlux pairs: C2H5O(40), C2H6O(55); C7H16(1), C7H15(687);\nEstimated using template [C/H3/Cs\\OneNonDe;O_sec_rad] for rate rule [C/H3/Cs\\H2\\Cs;O_rad/NonDeC]\nEuclidian distance = 1.4142135623730951\nMultiplied by reaction path degeneracy 6.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(687) + C7H16(1) <=> C7H15(686) + C7H16(1)',
#   'rate-constant': {'A': 0.004327734, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #997; RMG #4268\nTemplate reaction: H_Abstraction\nFlux pairs: C7H16(1), C7H15(686); C7H15(687), C7H16(1);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H2/Cs]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(687) + C7H16(1) <=> C7H15(683) + C7H16(1)',
#   'rate-constant': {'A': 0.004327734, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1000; RMG #4453\nTemplate reaction: H_Abstraction\nFlux pairs: C7H16(1), C7H15(683); C7H15(687), C7H16(1);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H2/Cs]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3O(31) + C7H16(1) <=> CH3OH(28) + C7H15(687)',
#   'rate-constant': {'A': 24000.0, 'b': 2.55, 'Ea0': 15.75, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1001; RMG #4509\nTemplate reaction: H_Abstraction\nFlux pairs: CH3O(31), CH3OH(28); C7H16(1), C7H15(687);\nEstimated using template [C/H3/Cs\\OneNonDe;O_sec_rad] for rate rule [C/H3/Cs\\H2\\Cs;O_rad/NonDeC]\nEuclidian distance = 1.4142135623730951\nMultiplied by reaction path degeneracy 6.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(687) + C7H16(1) <=> C7H15(684) + C7H16(1)',
#   'rate-constant': {'A': 0.002163867, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1005; RMG #4605\nTemplate reaction: H_Abstraction\nFlux pairs: C7H16(1), C7H15(684); C7H15(687), C7H16(1);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H2/Cs]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'H2O2(18) + C2H3(23) <=> HO2(17) + C2H4(11)',
#   'rate-constant': {'A': 2.0, 'b': 3.52, 'Ea0': -7.48, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1031; RMG #4991\nTemplate reaction: H_Abstraction\nFlux pairs: H2O2(18), HO2(17); C2H3(23), C2H4(11);\nMatched reaction 434 H2O2 + C2H3 <=> C2H4 + HO2_r3 in H_Abstraction/training\nThis reaction matched rate rule [Cd/H2/NonDeC;O_rad/NonDeO]\nfamily: H_Abstraction'},
#  {'equation': 'HO2(17) + HCCO(50) <=> O2(2) + CH2CO(25)',
#   'rate-constant': {'A': 0.02051684, 'b': 4.261, 'Ea0': 19.764, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1034; RMG #5021\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); HCCO(50), CH2CO(25);\nEstimated using template [X_H;Cd_Cdd_rad/H] for rate rule [Orad_O_H;Cd_Cdd_rad/H]\nEuclidian distance = 2.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3CHO(39) + C7H15(683) <=> CH2CHO(22) + C7H16(1)',
#   'rate-constant': {'A': 0.001148238, 'b': 4.287, 'Ea0': 6.424, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1077; RMG #5622\nTemplate reaction: H_Abstraction\nFlux pairs: CH3CHO(39), CH2CHO(22); C7H15(683), C7H16(1);\nEstimated using template [C/H3/OneDe;C_rad/H/NonDeC] for rate rule [C/H3/CO;C_rad/H/NonDeC]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 3.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3CHO(39) + C7H15(684) <=> CH2CHO(22) + C7H16(1)',
#   'rate-constant': {'A': 0.001148238, 'b': 4.287, 'Ea0': 6.424, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1078; RMG #5623\nTemplate reaction: H_Abstraction\nFlux pairs: CH3CHO(39), CH2CHO(22); C7H15(684), C7H16(1);\nEstimated using template [C/H3/OneDe;C_rad/H/NonDeC] for rate rule [C/H3/CO;C_rad/H/NonDeC]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 3.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3CHO(39) + C7H15(686) <=> CH2CHO(22) + C7H16(1)',
#   'rate-constant': {'A': 0.001148238, 'b': 4.287, 'Ea0': 6.424, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1079; RMG #5624\nTemplate reaction: H_Abstraction\nFlux pairs: CH3CHO(39), CH2CHO(22); C7H15(686), C7H16(1);\nEstimated using template [C/H3/OneDe;C_rad/H/NonDeC] for rate rule [C/H3/CO;C_rad/H/NonDeC]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 3.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3CHO(39) + C7H15(687) <=> CH2CHO(22) + C7H16(1)',
#   'rate-constant': {'A': 0.000515365, 'b': 4.471, 'Ea0': 5.188, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1080; RMG #5625\nTemplate reaction: H_Abstraction\nFlux pairs: CH3CHO(39), CH2CHO(22); C7H15(687), C7H16(1);\nEstimated using template [C/H3/OneDe;C_rad/H2/Cs] for rate rule [C/H3/CO;C_rad/H2/Cs]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 3.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H4O(43) + C7H15(683) <=> CH2CHO(22) + C7H16(1)',
#   'rate-constant': {'A': 0.6189024, 'b': 3.527, 'Ea0': 4.372, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1081; RMG #5630\nTemplate reaction: H_Abstraction\nFlux pairs: C2H4O(43), CH2CHO(22); C7H15(683), C7H16(1);\nEstimated using average of templates [O_sec;C_rad/H/NonDeC] + [O/H/OneDeC;Cs_rad] for rate rule [O/H/OneDeC;C_rad/H/NonDeC]\nEuclidian distance = 2.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H4O(43) + C7H15(684) <=> CH2CHO(22) + C7H16(1)',
#   'rate-constant': {'A': 0.6189024, 'b': 3.527, 'Ea0': 4.372, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1082; RMG #5631\nTemplate reaction: H_Abstraction\nFlux pairs: C2H4O(43), CH2CHO(22); C7H15(684), C7H16(1);\nEstimated using average of templates [O_sec;C_rad/H/NonDeC] + [O/H/OneDeC;Cs_rad] for rate rule [O/H/OneDeC;C_rad/H/NonDeC]\nEuclidian distance = 2.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H4O(43) + C7H15(686) <=> CH2CHO(22) + C7H16(1)',
#   'rate-constant': {'A': 0.6189024, 'b': 3.527, 'Ea0': 4.372, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1083; RMG #5632\nTemplate reaction: H_Abstraction\nFlux pairs: C2H4O(43), CH2CHO(22); C7H15(686), C7H16(1);\nEstimated using average of templates [O_sec;C_rad/H/NonDeC] + [O/H/OneDeC;Cs_rad] for rate rule [O/H/OneDeC;C_rad/H/NonDeC]\nEuclidian distance = 2.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H4O(43) + C7H15(687) <=> CH2CHO(22) + C7H16(1)',
#   'rate-constant': {'A': 0.0065, 'b': 4.245, 'Ea0': 7.2, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1084; RMG #5633\nTemplate reaction: H_Abstraction\nFlux pairs: C2H4O(43), CH2CHO(22); C7H15(687), C7H16(1);\nEstimated using template [O/H/OneDeC;C_pri_rad] for rate rule [O/H/OneDeC;C_rad/H2/Cs]\nEuclidian distance = 1.0\nfamily: H_Abstraction'},
#  {'equation': 'HO2(17) + CHCHO(48) <=> O2(2) + CH2CHO(22)',
#   'rate-constant': {'A': 49497470000.0, 'b': 0.0, 'Ea0': -1.637, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1085; RMG #5634\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); CHCHO(48), CH2CHO(22);\nEstimated using template [Orad_O_H;Y_rad_birad_trirad_quadrad] for rate rule [Orad_O_H;Y_1centerbirad]\nEuclidian distance = 1.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(683) + S(849) <=> S(829) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1092; RMG #4323\nTemplate reaction: H_Abstraction\nFlux pairs: S(849), S(829); C7H15(683), C7H16(1);\nEstimated using an average for rate rule [ROOH_sec;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'C7H15(684) + S(849) <=> S(829) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1093; RMG #4324\nTemplate reaction: H_Abstraction\nFlux pairs: S(849), S(829); C7H15(684), C7H16(1);\nEstimated using an average for rate rule [ROOH_sec;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'C7H15(686) + S(849) <=> S(829) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1094; RMG #4325\nTemplate reaction: H_Abstraction\nFlux pairs: S(849), S(829); C7H15(686), C7H16(1);\nEstimated using an average for rate rule [ROOH_sec;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'C7H15(687) + S(849) <=> S(829) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1095; RMG #4326\nTemplate reaction: H_Abstraction\nFlux pairs: S(849), S(829); C7H15(687), C7H16(1);\nEstimated using an average for rate rule [ROOH_sec;C_rad/H2/Cs]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'OH(15) + S(849) <=> H2O(8) + S(829)',
#   'rate-constant': {'A': 1100000000000.0, 'b': 0.0, 'Ea0': -0.437, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1096; RMG #5116\nTemplate reaction: H_Abstraction\nFlux pairs: S(849), S(829); OH(15), H2O(8);\nEstimated using template [O/H/NonDeO;O_pri_rad] for rate rule [ROOH_sec;O_pri_rad]\nEuclidian distance = 1.0\nfamily: H_Abstraction\nEa raised from -1.8 to -1.8 kJ/mol.'},
#  {'equation': 'CH2O(9) + S(829) <=> HCO(20) + S(849)',
#   'rate-constant': {'A': 41200.0, 'b': 2.5, 'Ea0': 10.21, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1097; RMG #5172\nTemplate reaction: H_Abstraction\nFlux pairs: S(829), S(849); CH2O(9), HCO(20);\nEstimated using template [CO_pri;O_rad/NonDeO] for rate rule [CO_pri;OOC]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H3(23) + S(849) <=> C2H4(11) + S(829)',
#   'rate-constant': {'A': 1.0, 'b': 3.52, 'Ea0': -7.48, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1098; RMG #5252\nTemplate reaction: H_Abstraction\nFlux pairs: S(849), S(829); C2H3(23), C2H4(11);\nEstimated using template [O/H/NonDeO;Cd_Cd\\H2_pri_rad] for rate rule [ROOH_sec;Cd_Cd\\H2_pri_rad]\nEuclidian distance = 1.0\nfamily: H_Abstraction'},
#  {'equation': 'HO2(17) + S(829) <=> O2(2) + S(849)',
#   'rate-constant': {'A': 120000000000.0, 'b': 0.0, 'Ea0': -1.95, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1102; RMG #5734\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); S(829), S(849);\nFrom training reaction 244 used for Orad_O_H;OOC\nExact match found for rate rule [Orad_O_H;OOC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -8.2 to -8.2 kJ/mol.'},
#  {'equation': 'HO2(17) + S(846) <=> O2(2) + S(849)',
#   'rate-constant': {'A': 0.02759059, 'b': 3.802, 'Ea0': 6.324, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1105; RMG #5737\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); S(846), S(849);\nEstimated using template [X_H;C_rad/H/NonDeC] for rate rule [Orad_O_H;C_rad/H/NonDeC]\nEuclidian distance = 2.0\nfamily: H_Abstraction'},
#  {'equation': 'S(846) + C7H16(1) <=> C7H15(683) + S(849)',
#   'rate-constant': {'A': 0.005147495, 'b': 4.29, 'Ea0': 7.713, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1106; RMG #5848\nTemplate reaction: H_Abstraction\nFlux pairs: S(846), S(849); C7H16(1), C7H15(683);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(684) + S(849) <=> S(846) + C7H16(1)',
#   'rate-constant': {'A': 0.002573748, 'b': 4.29, 'Ea0': 7.713, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1107; RMG #5849\nTemplate reaction: H_Abstraction\nFlux pairs: S(849), S(846); C7H15(684), C7H16(1);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'S(846) + C7H16(1) <=> C7H15(686) + S(849)',
#   'rate-constant': {'A': 0.005147495, 'b': 4.29, 'Ea0': 7.713, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1108; RMG #5850\nTemplate reaction: H_Abstraction\nFlux pairs: S(846), S(849); C7H16(1), C7H15(686);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(687) + S(849) <=> S(846) + C7H16(1)',
#   'rate-constant': {'A': 0.002163867, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1109; RMG #5851\nTemplate reaction: H_Abstraction\nFlux pairs: S(849), S(846); C7H15(687), C7H16(1);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H2/Cs]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(683) + S(906) <=> S(885) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1111; RMG #4489\nTemplate reaction: H_Abstraction\nFlux pairs: S(906), S(885); C7H15(683), C7H16(1);\nEstimated using an average for rate rule [ROOH_sec;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'C7H15(684) + S(906) <=> S(885) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1112; RMG #4490\nTemplate reaction: H_Abstraction\nFlux pairs: S(906), S(885); C7H15(684), C7H16(1);\nEstimated using an average for rate rule [ROOH_sec;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'C7H15(686) + S(906) <=> S(885) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1113; RMG #4491\nTemplate reaction: H_Abstraction\nFlux pairs: S(906), S(885); C7H15(686), C7H16(1);\nEstimated using an average for rate rule [ROOH_sec;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'C7H15(687) + S(906) <=> S(885) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1114; RMG #4492\nTemplate reaction: H_Abstraction\nFlux pairs: S(906), S(885); C7H15(687), C7H16(1);\nEstimated using an average for rate rule [ROOH_sec;C_rad/H2/Cs]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'S(903) + C7H16(1) <=> C7H15(683) + S(906)',
#   'rate-constant': {'A': 0.004327734, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1115; RMG #4899\nTemplate reaction: H_Abstraction\nFlux pairs: S(903), S(906); C7H16(1), C7H15(683);\nEstimated using template [C/H2/NonDeC;C_rad/H2/Cs] for rate rule [C/H2/NonDeC;C_rad/H2/Cs\\H2\\Cs|Cs|O]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'S(903) + C7H16(1) <=> C7H15(684) + S(906)',
#   'rate-constant': {'A': 0.002163867, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1116; RMG #4900\nTemplate reaction: H_Abstraction\nFlux pairs: S(903), S(906); C7H16(1), C7H15(684);\nEstimated using template [C/H2/NonDeC;C_rad/H2/Cs] for rate rule [C/H2/NonDeC;C_rad/H2/Cs\\H2\\Cs|Cs|O]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'S(903) + C7H16(1) <=> C7H15(686) + S(906)',
#   'rate-constant': {'A': 0.004327734, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1117; RMG #4901\nTemplate reaction: H_Abstraction\nFlux pairs: S(903), S(906); C7H16(1), C7H15(686);\nEstimated using template [C/H2/NonDeC;C_rad/H2/Cs] for rate rule [C/H2/NonDeC;C_rad/H2/Cs\\H2\\Cs|Cs|O]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'S(903) + C7H16(1) <=> C7H15(687) + S(906)',
#   'rate-constant': {'A': 0.0003260601, 'b': 4.81, 'Ea0': 8.49, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1118; RMG #4902\nTemplate reaction: H_Abstraction\nFlux pairs: S(903), S(906); C7H16(1), C7H15(687);\nEstimated using template [C/H3/Cs;C_rad/H2/Cs] for rate rule [C/H3/Cs\\H2\\Cs;C_rad/H2/Cs\\H2\\Cs|Cs|O]\nEuclidian distance = 2.23606797749979\nMultiplied by reaction path degeneracy 6.0\nfamily: H_Abstraction'},
#  {'equation': 'OH(15) + S(906) <=> H2O(8) + S(885)',
#   'rate-constant': {'A': 1100000000000.0, 'b': 0.0, 'Ea0': -0.437, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1119; RMG #5117\nTemplate reaction: H_Abstraction\nFlux pairs: S(906), S(885); OH(15), H2O(8);\nEstimated using template [O/H/NonDeO;O_pri_rad] for rate rule [ROOH_sec;O_pri_rad]\nEuclidian distance = 1.0\nfamily: H_Abstraction\nEa raised from -1.8 to -1.8 kJ/mol.'},
#  {'equation': 'CH2O(9) + S(885) <=> HCO(20) + S(906)',
#   'rate-constant': {'A': 41200.0, 'b': 2.5, 'Ea0': 10.21, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1120; RMG #5199\nTemplate reaction: H_Abstraction\nFlux pairs: S(885), S(906); CH2O(9), HCO(20);\nEstimated using template [CO_pri;O_rad/NonDeO] for rate rule [CO_pri;OOC]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H3(23) + S(906) <=> C2H4(11) + S(885)',
#   'rate-constant': {'A': 1.0, 'b': 3.52, 'Ea0': -7.48, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1121; RMG #5266\nTemplate reaction: H_Abstraction\nFlux pairs: S(906), S(885); C2H3(23), C2H4(11);\nEstimated using template [O/H/NonDeO;Cd_Cd\\H2_pri_rad] for rate rule [ROOH_sec;Cd_Cd\\H2_pri_rad]\nEuclidian distance = 1.0\nfamily: H_Abstraction'},
#  {'equation': 'HO2(17) + S(885) <=> O2(2) + S(906)',
#   'rate-constant': {'A': 120000000000.0, 'b': 0.0, 'Ea0': -1.95, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1125; RMG #5924\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); S(885), S(906);\nFrom training reaction 244 used for Orad_O_H;OOC\nExact match found for rate rule [Orad_O_H;OOC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -8.2 to -8.2 kJ/mol.'},
#  {'equation': 'HO2(17) + S(903) <=> O2(2) + S(906)',
#   'rate-constant': {'A': 5.75, 'b': 2.94, 'Ea0': 0.46, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1126; RMG #5931\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); S(903), S(906);\nEstimated using template [X_H;C_rad/H2/Cs\\H2\\Cs|Cs|O] for rate rule [Orad_O_H;C_rad/H2/Cs\\H2\\Cs|Cs|O]\nEuclidian distance = 2.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(683) + S(1085) <=> S(987) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1127; RMG #4943\nTemplate reaction: H_Abstraction\nFlux pairs: S(1085), S(987); C7H15(683), C7H16(1);\nEstimated using an average for rate rule [ROOH_pri;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'C7H15(684) + S(1085) <=> S(987) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1128; RMG #4944\nTemplate reaction: H_Abstraction\nFlux pairs: S(1085), S(987); C7H15(684), C7H16(1);\nEstimated using an average for rate rule [ROOH_pri;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'C7H15(686) + S(1085) <=> S(987) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1129; RMG #4945\nTemplate reaction: H_Abstraction\nFlux pairs: S(1085), S(987); C7H15(686), C7H16(1);\nEstimated using an average for rate rule [ROOH_pri;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'C7H15(687) + S(1085) <=> S(987) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1130; RMG #4946\nTemplate reaction: H_Abstraction\nFlux pairs: S(1085), S(987); C7H15(687), C7H16(1);\nEstimated using an average for rate rule [ROOH_pri;C_rad/H2/Cs]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'HO2(17) + S(987) <=> O2(2) + S(1085)',
#   'rate-constant': {'A': 120000000000.0, 'b': 0.0, 'Ea0': -1.95, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1136; RMG #5950\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); S(987), S(1085);\nFrom training reaction 244 used for Orad_O_H;OOC\nExact match found for rate rule [Orad_O_H;OOC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -8.2 to -8.2 kJ/mol.'},
#  {'equation': 'HO2(17) + S(904) <=> O2(2) + S(906)',
#   'rate-constant': {'A': 0.02759059, 'b': 3.802, 'Ea0': 6.324, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1141; RMG #5929\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); S(904), S(906);\nEstimated using template [X_H;C_rad/H/NonDeC] for rate rule [Orad_O_H;C_rad/H/NonDeC]\nEuclidian distance = 2.0\nfamily: H_Abstraction'},
#  {'equation': 'S(904) + C7H16(1) <=> C7H15(683) + S(906)',
#   'rate-constant': {'A': 0.005147495, 'b': 4.29, 'Ea0': 7.713, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1142; RMG #6022\nTemplate reaction: H_Abstraction\nFlux pairs: S(904), S(906); C7H16(1), C7H15(683);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(684) + S(906) <=> S(904) + C7H16(1)',
#   'rate-constant': {'A': 0.002573748, 'b': 4.29, 'Ea0': 7.713, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1143; RMG #6023\nTemplate reaction: H_Abstraction\nFlux pairs: S(906), S(904); C7H15(684), C7H16(1);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'S(904) + C7H16(1) <=> C7H15(686) + S(906)',
#   'rate-constant': {'A': 0.005147495, 'b': 4.29, 'Ea0': 7.713, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1144; RMG #6024\nTemplate reaction: H_Abstraction\nFlux pairs: S(904), S(906); C7H16(1), C7H15(686);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(687) + S(906) <=> S(904) + C7H16(1)',
#   'rate-constant': {'A': 0.002163867, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1145; RMG #6025\nTemplate reaction: H_Abstraction\nFlux pairs: S(906), S(904); C7H15(687), C7H16(1);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H2/Cs]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H5O(44) + C7H16(1) <=> C2H6O(55) + C7H15(683)',
#   'rate-constant': {'A': 0.004327734, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1217; RMG #6439\nTemplate reaction: H_Abstraction\nFlux pairs: C2H5O(44), C2H6O(55); C7H16(1), C7H15(683);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H2/Cs]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H5O(44) + C7H16(1) <=> C2H6O(55) + C7H15(684)',
#   'rate-constant': {'A': 0.002163867, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1218; RMG #6440\nTemplate reaction: H_Abstraction\nFlux pairs: C2H5O(44), C2H6O(55); C7H16(1), C7H15(684);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H2/Cs]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H5O(44) + C7H16(1) <=> C2H6O(55) + C7H15(686)',
#   'rate-constant': {'A': 0.004327734, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1219; RMG #6441\nTemplate reaction: H_Abstraction\nFlux pairs: C2H5O(44), C2H6O(55); C7H16(1), C7H15(686);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H2/Cs]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H5O(44) + C7H16(1) <=> C2H6O(55) + C7H15(687)',
#   'rate-constant': {'A': 0.0003260601, 'b': 4.81, 'Ea0': 8.49, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1220; RMG #6442\nTemplate reaction: H_Abstraction\nFlux pairs: C2H5O(44), C2H6O(55); C7H16(1), C7H15(687);\nEstimated using template [C/H3/Cs;C_rad/H2/Cs] for rate rule [C/H3/Cs\\H2\\Cs;C_rad/H2/Cs]\nEuclidian distance = 2.0\nMultiplied by reaction path degeneracy 6.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(683) + S(1310) <=> S(1286) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1233; RMG #5891\nTemplate reaction: H_Abstraction\nFlux pairs: S(1310), S(1286); C7H15(683), C7H16(1);\nEstimated using an average for rate rule [ROOH_sec;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'C7H15(684) + S(1310) <=> S(1286) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1234; RMG #5892\nTemplate reaction: H_Abstraction\nFlux pairs: S(1310), S(1286); C7H15(684), C7H16(1);\nEstimated using an average for rate rule [ROOH_sec;C_rad/H/NonDeC]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
# ...
#  {'equation': 'C2H3O3(60) + S(906) <=> C2H4O3(67) + S(885)',
#   'rate-constant': {'A': 0.092, 'b': 3.96, 'Ea0': 6.63, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1934; RMG #19526\nTemplate reaction: H_Abstraction\nFlux pairs: C2H3O3(60), C2H4O3(67); S(906), S(885);\nEstimated using template [O/H/NonDeO;OOC] for rate rule [ROOH_sec;OOC]\nEuclidian distance = 1.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H3O3(60) + S(906) <=> C2H4O3(67) + S(904)',
#   'rate-constant': {'A': 288083.3, 'b': 2.156, 'Ea0': 12.851, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1935; RMG #19531\nTemplate reaction: H_Abstraction\nFlux pairs: C2H3O3(60), C2H4O3(67); S(906), S(904);\nEstimated using average of templates [C_sec;OOC] + [C/H2/NonDeC;O_rad/NonDeO] for rate rule [C/H2/NonDeC;OOC]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H4O3(67) + S(903) <=> C2H3O3(60) + S(906)',
#   'rate-constant': {'A': 5.75, 'b': 2.94, 'Ea0': 0.46, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1936; RMG #19533\nTemplate reaction: H_Abstraction\nFlux pairs: C2H4O3(67), C2H3O3(60); S(903), S(906);\nEstimated using an average for rate rule [O/H/NonDeO;C_rad/H2/Cs\\H2\\Cs|Cs|O]\nEuclidian distance = 0\nfamily: H_Abstraction'},
#  {'equation': 'C2H3O3(60) + S(1085) <=> C2H4O3(67) + S(987)',
#   'rate-constant': {'A': 0.092, 'b': 3.96, 'Ea0': 6.63, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1937; RMG #19550\nTemplate reaction: H_Abstraction\nFlux pairs: C2H3O3(60), C2H4O3(67); S(1085), S(987);\nEstimated using template [O/H/NonDeO;OOC] for rate rule [ROOH_pri;OOC]\nEuclidian distance = 1.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H3O3(60) + S(1085) <=> C2H4O3(67) + S(1082)',
#   'rate-constant': {'A': 288083.3, 'b': 2.156, 'Ea0': 12.851, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1938; RMG #19552\nTemplate reaction: H_Abstraction\nFlux pairs: C2H3O3(60), C2H4O3(67); S(1085), S(1082);\nEstimated using average of templates [C_sec;OOC] + [C/H2/NonDeC;O_rad/NonDeO] for rate rule [C/H2/NonDeC;OOC]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H3O3(60) + S(1310) <=> C2H4O3(67) + S(1309)',
#   'rate-constant': {'A': 0.092, 'b': 3.96, 'Ea0': 6.63, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1939; RMG #19673\nTemplate reaction: H_Abstraction\nFlux pairs: C2H3O3(60), C2H4O3(67); S(1310), S(1309);\nEstimated using template [O/H/NonDeO;OOC] for rate rule [ROOH_sec;OOC]\nEuclidian distance = 1.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H3O3(60) + S(1310) <=> C2H4O3(67) + S(1286)',
#   'rate-constant': {'A': 0.092, 'b': 3.96, 'Ea0': 6.63, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1940; RMG #19674\nTemplate reaction: H_Abstraction\nFlux pairs: C2H3O3(60), C2H4O3(67); S(1310), S(1286);\nEstimated using template [O/H/NonDeO;OOC] for rate rule [ROOH_sec;OOC]\nEuclidian distance = 1.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H4O3(67) + S(1306) <=> C2H3O3(60) + S(1310)',
#   'rate-constant': {'A': 5.75, 'b': 2.94, 'Ea0': 0.46, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1941; RMG #19681\nTemplate reaction: H_Abstraction\nFlux pairs: C2H4O3(67), C2H3O3(60); S(1306), S(1310);\nEstimated using an average for rate rule [O/H/NonDeO;C_rad/H2/Cs\\H2\\Cs|Cs|O]\nEuclidian distance = 0\nfamily: H_Abstraction'},
#  {'equation': 'O(5) + S(849) <=> OH(15) + S(846)',
#   'rate-constant': {'A': 1109.346, 'b': 3.19, 'Ea0': 14.117, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1963; RMG #20900\nTemplate reaction: H_Abstraction\nFlux pairs: O(5), OH(15); S(849), S(846);\nEstimated using an average for rate rule [C/H2/NonDeC;O_atom_triplet]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'O(5) + S(849) <=> OH(15) + S(845)',
#   'rate-constant': {'A': 169.0, 'b': 3.43, 'Ea0': 13.72, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1964; RMG #20901\nTemplate reaction: H_Abstraction\nFlux pairs: O(5), OH(15); S(849), S(845);\nFrom training reaction 784 used for C/H2/Cs/Cs\\Cs|O;O_atom_triplet\nExact match found for rate rule [C/H2/Cs/Cs\\Cs|O;O_atom_triplet]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'O(5) + S(906) <=> OH(15) + S(904)',
#   'rate-constant': {'A': 1109.346, 'b': 3.19, 'Ea0': 14.117, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1965; RMG #20918\nTemplate reaction: H_Abstraction\nFlux pairs: O(5), OH(15); S(906), S(904);\nEstimated using an average for rate rule [C/H2/NonDeC;O_atom_triplet]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'O(5) + S(906) <=> OH(15) + S(903)',
#   'rate-constant': {'A': 0.3008338, 'b': 4.05, 'Ea0': 4.08, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1966; RMG #20920\nTemplate reaction: H_Abstraction\nFlux pairs: O(5), OH(15); S(906), S(903);\nEstimated using average of templates [C/H3/Cs\\OneNonDe;O_atom_triplet] + [C/H3/Cs\\H2\\Cs|O;Y_rad_birad_trirad_quadrad] for rate rule\n[C/H3/Cs\\H2\\Cs|O;O_atom_triplet]\nEuclidian distance = 2.0\nMultiplied by reaction path degeneracy 3.0\nfamily: H_Abstraction'},
#  {'equation': 'O(5) + S(1085) <=> OH(15) + S(1082)',
#   'rate-constant': {'A': 1109.346, 'b': 3.19, 'Ea0': 14.117, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1967; RMG #20922\nTemplate reaction: H_Abstraction\nFlux pairs: O(5), OH(15); S(1085), S(1082);\nEstimated using an average for rate rule [C/H2/NonDeC;O_atom_triplet]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'O(5) + S(1310) <=> OH(15) + S(1306)',
#   'rate-constant': {'A': 0.3008338, 'b': 4.05, 'Ea0': 4.08, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1968; RMG #20952\nTemplate reaction: H_Abstraction\nFlux pairs: O(5), OH(15); S(1310), S(1306);\nEstimated using average of templates [C/H3/Cs\\OneNonDe;O_atom_triplet] + [C/H3/Cs\\H2\\Cs|O;Y_rad_birad_trirad_quadrad] for rate rule\n[C/H3/Cs\\H2\\Cs|O;O_atom_triplet]\nEuclidian distance = 2.0\nMultiplied by reaction path degeneracy 3.0\nfamily: H_Abstraction'},
#  {'equation': 'CH2O(9) + S(987) <=> HCO(20) + S(1085)',
#   'rate-constant': {'A': 41200.0, 'b': 2.5, 'Ea0': 10.21, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2007; RMG #23435\nTemplate reaction: H_Abstraction\nFlux pairs: S(987), S(1085); CH2O(9), HCO(20);\nEstimated using template [CO_pri;O_rad/NonDeO] for rate rule [CO_pri;OOC]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'CH2O(9) + S(1286) <=> HCO(20) + S(1310)',
#   'rate-constant': {'A': 41200.0, 'b': 2.5, 'Ea0': 10.21, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2008; RMG #23482\nTemplate reaction: H_Abstraction\nFlux pairs: S(1286), S(1310); CH2O(9), HCO(20);\nEstimated using template [CO_pri;O_rad/NonDeO] for rate rule [CO_pri;OOC]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'CH2O(9) + S(1309) <=> HCO(20) + S(1310)',
#   'rate-constant': {'A': 41200.0, 'b': 2.5, 'Ea0': 10.21, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2009; RMG #23501\nTemplate reaction: H_Abstraction\nFlux pairs: S(1309), S(1310); CH2O(9), HCO(20);\nEstimated using template [CO_pri;O_rad/NonDeO] for rate rule [CO_pri;OOC]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H3(23) + S(1085) <=> C2H4(11) + S(987)',
#   'rate-constant': {'A': 1.0, 'b': 3.52, 'Ea0': -7.48, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2014; RMG #23992\nTemplate reaction: H_Abstraction\nFlux pairs: S(1085), S(987); C2H3(23), C2H4(11);\nEstimated using template [O/H/NonDeO;Cd_Cd\\H2_pri_rad] for rate rule [ROOH_pri;Cd_Cd\\H2_pri_rad]\nEuclidian distance = 1.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H3(23) + S(1310) <=> C2H4(11) + S(1286)',
#   'rate-constant': {'A': 1.0, 'b': 3.52, 'Ea0': -7.48, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2015; RMG #24002\nTemplate reaction: H_Abstraction\nFlux pairs: S(1310), S(1286); C2H3(23), C2H4(11);\nEstimated using template [O/H/NonDeO;Cd_Cd\\H2_pri_rad] for rate rule [ROOH_sec;Cd_Cd\\H2_pri_rad]\nEuclidian distance = 1.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H3(23) + S(1310) <=> C2H4(11) + S(1309)',
#   'rate-constant': {'A': 1.0, 'b': 3.52, 'Ea0': -7.48, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2016; RMG #24012\nTemplate reaction: H_Abstraction\nFlux pairs: S(1310), S(1309); C2H3(23), C2H4(11);\nEstimated using template [O/H/NonDeO;Cd_Cd\\H2_pri_rad] for rate rule [ROOH_sec;Cd_Cd\\H2_pri_rad]\nEuclidian distance = 1.0\nfamily: H_Abstraction'},
#  {'equation': 'H(14) + S(1310) <=> H2(13) + S(1286)',
#   'rate-constant': {'A': 64.06374, 'b': 2.8, 'Ea0': 10.182, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2017; RMG #24748\nTemplate reaction: H_Abstraction\nFlux pairs: S(1310), S(1286); H(14), H2(13);\nEstimated using average of templates [O/H/NonDeO;H_rad] + [ROOH_sec;Y_rad] for rate rule [ROOH_sec;H_rad]\nEuclidian distance = 1.0\nfamily: H_Abstraction'},
#  {'equation': 'S(903) + S(1085) <=> S(1082) + S(906)',
#   'rate-constant': {'A': 0.002163867, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2018; RMG #27561\nTemplate reaction: H_Abstraction\nFlux pairs: S(903), S(906); S(1085), S(1082);\nEstimated using template [C/H2/NonDeC;C_rad/H2/Cs] for rate rule [C/H2/NonDeC;C_rad/H2/Cs\\H2\\Cs|Cs|O]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'S(1306) + S(906) <=> S(903) + S(1310)',
#   'rate-constant': {'A': 0.0001630301, 'b': 4.81, 'Ea0': 8.49, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2019; RMG #27580\nTemplate reaction: H_Abstraction\nFlux pairs: S(906), S(903); S(1306), S(1310);\nEstimated using template [C/H3/Cs;C_rad/H2/Cs] for rate rule [C/H3/Cs\\H2\\Cs|O;C_rad/H2/Cs\\H2\\Cs|Cs|O]\nEuclidian distance = 3.1622776601683795\nMultiplied by reaction path degeneracy 3.0\nfamily: H_Abstraction'},
#  {'equation': 'S(845) + S(849) <=> S(846) + S(849)',
#   'rate-constant': {'A': 0.002573748, 'b': 4.29, 'Ea0': 7.713, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2020; RMG #28822\nTemplate reaction: H_Abstraction\nFlux pairs: S(849), S(846); S(845), S(849);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'S(1306) + S(849) <=> S(846) + S(1310)',
#   'rate-constant': {'A': 0.002163867, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2021; RMG #28828\nTemplate reaction: H_Abstraction\nFlux pairs: S(1306), S(1310); S(849), S(846);\nEstimated using template [C/H2/NonDeC;C_rad/H2/Cs] for rate rule [C/H2/NonDeC;C_rad/H2/Cs\\H2\\Cs|Cs|O]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'S(1306) + S(849) <=> S(845) + S(1310)',
#   'rate-constant': {'A': 0.002163867, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2022; RMG #28829\nTemplate reaction: H_Abstraction\nFlux pairs: S(1306), S(1310); S(849), S(845);\nEstimated using template [C/H2/NonDeC;C_rad/H2/Cs] for rate rule [C/H2/Cs/Cs\\Cs|O;C_rad/H2/Cs\\H2\\Cs|Cs|O]\nEuclidian distance = 1.4142135623730951\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'S(846) + S(906) <=> S(904) + S(849)',
#   'rate-constant': {'A': 0.002573748, 'b': 4.29, 'Ea0': 7.713, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2023; RMG #28835\nTemplate reaction: H_Abstraction\nFlux pairs: S(906), S(904); S(846), S(849);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'S(845) + S(906) <=> S(904) + S(849)',
#   'rate-constant': {'A': 0.002573748, 'b': 4.29, 'Ea0': 7.713, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2024; RMG #28836\nTemplate reaction: H_Abstraction\nFlux pairs: S(906), S(904); S(845), S(849);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'S(1082) + S(849) <=> S(846) + S(1085)',
#   'rate-constant': {'A': 0.002573748, 'b': 4.29, 'Ea0': 7.713, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2025; RMG #29046\nTemplate reaction: H_Abstraction\nFlux pairs: S(849), S(846); S(1082), S(1085);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'S(1306) + S(906) <=> S(904) + S(1310)',
#   'rate-constant': {'A': 0.002163867, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2026; RMG #29718\nTemplate reaction: H_Abstraction\nFlux pairs: S(1306), S(1310); S(906), S(904);\nEstimated using template [C/H2/NonDeC;C_rad/H2/Cs] for rate rule [C/H2/NonDeC;C_rad/H2/Cs\\H2\\Cs|Cs|O]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'S(1306) + S(1085) <=> S(1082) + S(1310)',
#   'rate-constant': {'A': 0.002163867, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2027; RMG #29918\nTemplate reaction: H_Abstraction\nFlux pairs: S(1306), S(1310); S(1085), S(1082);\nEstimated using template [C/H2/NonDeC;C_rad/H2/Cs] for rate rule [C/H2/NonDeC;C_rad/H2/Cs\\H2\\Cs|Cs|O]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'S(1082) + S(906) <=> S(904) + S(1085)',
#   'rate-constant': {'A': 0.002573748, 'b': 4.29, 'Ea0': 7.713, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2028; RMG #29925\nTemplate reaction: H_Abstraction\nFlux pairs: S(906), S(904); S(1082), S(1085);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3CHO(39) + C7H15(683) <=> CH3CO(21) + C7H16(1)',
#   'rate-constant': {'A': 0.000194, 'b': 4.68, 'Ea0': 6.31, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2068; RMG #36935\nTemplate reaction: H_Abstraction\nFlux pairs: CH3CHO(39), CH3CO(21); C7H15(683), C7H16(1);\nEstimated using template [CO/H/Cs;C_sec_rad] for rate rule [CO/H/Cs;C_rad/H/NonDeC]\nEuclidian distance = 1.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3CHO(39) + C7H15(684) <=> CH3CO(21) + C7H16(1)',
#   'rate-constant': {'A': 0.000194, 'b': 4.68, 'Ea0': 6.31, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2069; RMG #36936\nTemplate reaction: H_Abstraction\nFlux pairs: CH3CHO(39), CH3CO(21); C7H15(684), C7H16(1);\nEstimated using template [CO/H/Cs;C_sec_rad] for rate rule [CO/H/Cs;C_rad/H/NonDeC]\nEuclidian distance = 1.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3CHO(39) + C7H15(686) <=> CH3CO(21) + C7H16(1)',
#   'rate-constant': {'A': 0.000194, 'b': 4.68, 'Ea0': 6.31, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2070; RMG #36937\nTemplate reaction: H_Abstraction\nFlux pairs: CH3CHO(39), CH3CO(21); C7H15(686), C7H16(1);\nEstimated using template [CO/H/Cs;C_sec_rad] for rate rule [CO/H/Cs;C_rad/H/NonDeC]\nEuclidian distance = 1.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3CHO(39) + C7H15(687) <=> CH3CO(21) + C7H16(1)',
#   'rate-constant': {'A': 380000000000.0, 'b': 0.0, 'Ea0': 7.21, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #2071; RMG #36938\nTemplate reaction: H_Abstraction\nFlux pairs: CH3CHO(39), CH3CO(21); C7H15(687), C7H16(1);\nEstimated using template [CO/H/Cs;C_pri_rad] for rate rule [CO/H/Cs;C_rad/H2/Cs]\nEuclidian distance = 1.0\nfamily: H_Abstraction'}]

# %%
for i in range(len(model['reactions'])):
    if model['reactions'][i] ==
# Out:
# [{'equation': 'O2(2) + H(14) <=> O(5) + OH(15)',
#   'rate-constant': {'A': 104000000000000.0, 'b': 0.0, 'Ea': 15.286},
#   'note': 'Reaction index: Chemkin #1; RMG #1\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: O2(2), OH(15); H(14), O(5);'},
#  {'equation': 'O(5) + H2(13) <=> H(14) + OH(15)',
#   'duplicate': True,
#   'rate-constant': {'A': 3818000000000.0, 'b': 0.0, 'Ea': 7.948},
#   'note': 'Reaction index: Chemkin #2; RMG #2\nLibrary reaction: BurkeH2O2inN2'},
#  {'equation': 'O(5) + H2(13) <=> H(14) + OH(15)',
#   'duplicate': True,
#   'rate-constant': {'A': 879200000000000.0, 'b': 0.0, 'Ea': 19.17},
#   'note': 'Reaction index: Chemkin #3; RMG #2\nLibrary reaction: BurkeH2O2inN2'},
#  {'equation': 'OH(15) + H2(13) <=> H(14) + H2O(8)',
#   'rate-constant': {'A': 216000000.0, 'b': 1.51, 'Ea': 3.43},
#   'note': 'Reaction index: Chemkin #4; RMG #3\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: OH(15), H2O(8); H2(13), H(14);'},
#  {'equation': 'OH(15) + OH(15) <=> O(5) + H2O(8)',
#   'rate-constant': {'A': 33400.0, 'b': 2.42, 'Ea': -1.93},
#   'note': 'Reaction index: Chemkin #5; RMG #4\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: OH(15), H2O(8); OH(15), O(5);'},
#  {'equation': 'H2(13) + M <=> H(14) + H(14) + M',
#   'type': 'three-body',
#   'rate-constant': {'A': 4.577e+19, 'b': -1.4, 'Ea': 104.38},
#   'efficiencies': {'H2(13)': 2.5,
#    'H2O(8)': 12.0,
#    'CO(6)': 1.9,
#    'CO2(7)': 3.8,
#    'Ar': 0.0,
#    'He(16)': 0.0},
#   'note': 'Reaction index: Chemkin #6; RMG #5\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: H2(13), H(14); H2(13), H(14);'},
#  {'equation': 'Ar + H2(13) <=> Ar + H(14) + H(14)',
#   'rate-constant': {'A': 5.84e+18, 'b': -1.1, 'Ea': 104.38},
#   'note': 'Reaction index: Chemkin #7; RMG #6\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: H2(13), H(14); Ar, Ar; Ar, H(14);'},
#  {'equation': 'He(16) + H2(13) <=> He(16) + H(14) + H(14)',
#   'rate-constant': {'A': 5.84e+18, 'b': -1.1, 'Ea': 104.38},
#   'note': 'Reaction index: Chemkin #8; RMG #7\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: H2(13), H(14); He(16), He(16); He(16), H(14);'},
#  {'equation': 'O(5) + O(5) + M <=> O2(2) + M',
#   'type': 'three-body',
#   'rate-constant': {'A': 6165000000000000.0, 'b': -0.5, 'Ea': 0.0},
#   'efficiencies': {'H2(13)': 2.5,
#    'CO(6)': 1.9,
#    'Ar': 0.0,
#    'CO2(7)': 3.8,
#    'H2O(8)': 12.0,
#    'He(16)': 0.0},
#   'note': 'Reaction index: Chemkin #9; RMG #8\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: O(5), O2(2); O(5), O2(2);'},
#  {'equation': 'Ar + O(5) + O(5) <=> Ar + O2(2)',
#   'rate-constant': {'A': 18860000000000.0, 'b': 0.0, 'Ea': -1.788},
#   'note': 'Reaction index: Chemkin #10; RMG #9\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: O(5), O2(2); Ar, Ar; O(5), Ar;'},
#  {'equation': 'He(16) + O(5) + O(5) <=> He(16) + O2(2)',
#   'rate-constant': {'A': 18860000000000.0, 'b': 0.0, 'Ea': -1.788},
#   'note': 'Reaction index: Chemkin #11; RMG #10\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: O(5), O2(2); He(16), He(16); O(5), He(16);'},
#  {'equation': 'O(5) + H(14) + M <=> OH(15) + M',
#   'type': 'three-body',
#   'rate-constant': {'A': 4.714e+18, 'b': -1.0, 'Ea': 0.0},
#   'efficiencies': {'H2(13)': 2.5,
#    'H2O(8)': 12.0,
#    'CO(6)': 1.9,
#    'CO2(7)': 3.8,
#    'Ar': 0.75,
#    'He(16)': 0.75},
#   'note': 'Reaction index: Chemkin #12; RMG #11\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: O(5), OH(15); H(14), OH(15);'},
#  {'equation': 'H2O(8) + M <=> H(14) + OH(15) + M',
#   'type': 'three-body',
#   'rate-constant': {'A': 6.064e+27, 'b': -3.322, 'Ea': 120.79},
#   'efficiencies': {'H2(13)': 3.0,
#    'H2O(8)': 0.0,
#    'CO(6)': 1.9,
#    'CO2(7)': 3.8,
#    'O2(2)': 1.5,
#    'He(16)': 1.1,
#    'N2': 2.0},
#   'note': 'Reaction index: Chemkin #13; RMG #12\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: H2O(8), H(14); H2O(8), OH(15);'},
#  {'equation': 'H2O(8) + H2O(8) <=> H(14) + OH(15) + H2O(8)',
#   'rate-constant': {'A': 1.006e+26, 'b': -2.44, 'Ea': 120.18},
#   'note': 'Reaction index: Chemkin #14; RMG #13\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: H2O(8), H2O(8); H2O(8), H(14); H2O(8), OH(15);'},
#  {'equation': 'O2(2) + H(14) (+M) <=> HO2(17) (+M)',
#   'type': 'falloff',
#   'low-P-rate-constant': {'A': 6.366e+20, 'b': -1.72, 'Ea': 0.525},
#   'high-P-rate-constant': {'A': 4651000000000.0, 'b': 0.44, 'Ea': 0.0},
#   'Troe': {'A': 0.5, 'T3': 1e-30, 'T1': 1e+30},
#   'efficiencies': {'O2(2)': 0.78,
#    'H2(13)': 2.0,
#    'CO(6)': 1.9,
#    'CO2(7)': 3.8,
#    'H2O(8)': 14.0,
#    'He(16)': 0.8,
#    'Ar': 0.67},
#   'note': 'Reaction index: Chemkin #15; RMG #14\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: O2(2), HO2(17); H(14), HO2(17);'},
#  {'equation': 'H(14) + HO2(17) <=> O2(2) + H2(13)',
#   'rate-constant': {'A': 2750000.0, 'b': 2.09, 'Ea': -1.451},
#   'note': 'Reaction index: Chemkin #16; RMG #15\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: HO2(17), O2(2); H(14), H2(13);'},
#  {'equation': 'H(14) + HO2(17) <=> OH(15) + OH(15)',
#   'rate-constant': {'A': 70790000000000.0, 'b': 0.0, 'Ea': 0.295},
#   'note': 'Reaction index: Chemkin #17; RMG #16\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: HO2(17), OH(15); H(14), OH(15);'},
#  {'equation': 'O(5) + HO2(17) <=> O2(2) + OH(15)',
#   'rate-constant': {'A': 28500000000.0, 'b': 1.0, 'Ea': -0.724},
#   'note': 'Reaction index: Chemkin #18; RMG #17\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: HO2(17), O2(2); O(5), OH(15);'},
#  {'equation': 'OH(15) + HO2(17) <=> O2(2) + H2O(8)',
#   'rate-constant': {'A': 28900000000000.0, 'b': 0.0, 'Ea': -0.497},
#   'note': 'Reaction index: Chemkin #19; RMG #18\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: HO2(17), O2(2); OH(15), H2O(8);'},
#  {'equation': 'HO2(17) + HO2(17) <=> O2(2) + H2O2(18)',
#   'duplicate': True,
#   'rate-constant': {'A': 420000000000000.0, 'b': 0.0, 'Ea': 11.982},
#   'note': 'Reaction index: Chemkin #20; RMG #19\nLibrary reaction: BurkeH2O2inN2'},
#  {'equation': 'HO2(17) + HO2(17) <=> O2(2) + H2O2(18)',
#   'duplicate': True,
#   'rate-constant': {'A': 130000000000.0, 'b': 0.0, 'Ea': -1.629},
#   'note': 'Reaction index: Chemkin #21; RMG #19\nLibrary reaction: BurkeH2O2inN2'},
#  {'equation': 'H2O2(18) (+M) <=> OH(15) + OH(15) (+M)',
#   'type': 'falloff',
#   'low-P-rate-constant': {'A': 2.49e+24, 'b': -2.3, 'Ea': 48.749},
#   'high-P-rate-constant': {'A': 2000000000000.0, 'b': 0.9, 'Ea': 48.749},
#   'Troe': {'A': 0.43, 'T3': 1e-30, 'T1': 1e+30},
#   'efficiencies': {'H2(13)': 3.7,
#    'H2O(8)': 7.5,
#    'O2(2)': 1.2,
#    'N2': 1.5,
#    'CO(6)': 2.8,
#    'H2O2(18)': 7.7,
#    'CO2(7)': 1.6,
#    'He(16)': 0.65},
#   'note': 'Reaction index: Chemkin #22; RMG #20\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: H2O2(18), OH(15); H2O2(18), OH(15);'},
#  {'equation': 'H(14) + H2O2(18) <=> OH(15) + H2O(8)',
#   'rate-constant': {'A': 24100000000000.0, 'b': 0.0, 'Ea': 3.97},
#   'note': 'Reaction index: Chemkin #23; RMG #21\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: H2O2(18), H2O(8); H(14), OH(15);'},
#  {'equation': 'H(14) + H2O2(18) <=> HO2(17) + H2(13)',
#   'rate-constant': {'A': 48200000000000.0, 'b': 0.0, 'Ea': 7.95},
#   'note': 'Reaction index: Chemkin #24; RMG #22\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: H2O2(18), HO2(17); H(14), H2(13);'},
#  {'equation': 'O(5) + H2O2(18) <=> OH(15) + HO2(17)',
#   'rate-constant': {'A': 9550000.0, 'b': 2.0, 'Ea': 3.97},
#   'note': 'Reaction index: Chemkin #25; RMG #23\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: H2O2(18), HO2(17); O(5), OH(15);'},
#  {'equation': 'OH(15) + H2O2(18) <=> HO2(17) + H2O(8)',
#   'duplicate': True,
#   'rate-constant': {'A': 1740000000000.0, 'b': 0.0, 'Ea': 0.318},
#   'note': 'Reaction index: Chemkin #26; RMG #24\nLibrary reaction: BurkeH2O2inN2'},
#  {'equation': 'OH(15) + H2O2(18) <=> HO2(17) + H2O(8)',
#   'duplicate': True,
#   'rate-constant': {'A': 75900000000000.0, 'b': 0.0, 'Ea': 7.27},
#   'note': 'Reaction index: Chemkin #27; RMG #24\nLibrary reaction: BurkeH2O2inN2'},
#  {'equation': 'H(14) + HO2(17) <=> O(5) + H2O(8)',
#   'rate-constant': {'A': 290000000.0, 'b': 1.55, 'Ea': -0.16},
#   'note': 'Reaction index: Chemkin #28; RMG #25\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: HO2(17), H2O(8); H(14), O(5);'},
#  {'equation': 'H(14) + HO2(17) + M <=> H2O2(18) + M',
#   'type': 'three-body',
#   'rate-constant': {'A': 600000000000000.0, 'b': 1.25, 'Ea': -0.27},
#   'note': 'Reaction index: Chemkin #29; RMG #26\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: H(14), H2O2(18); HO2(17), H2O2(18);'},
#  {'equation': 'OH(15) + OH(15) <=> O2(2) + H2(13)',
#   'rate-constant': {'A': 200000000000.0, 'b': 0.51, 'Ea': 50.5},
#   'note': 'Reaction index: Chemkin #30; RMG #27\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: OH(15), O2(2); OH(15), H2(13);'},
#  {'equation': 'O(5) + H2O(8) <=> O2(2) + H2(13)',
#   'rate-constant': {'A': 10700000000.0, 'b': 0.97, 'Ea': 68.7},
#   'note': 'Reaction index: Chemkin #31; RMG #28\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: H2O(8), O2(2); O(5), H2(13);'},
#  {'equation': 'O(5) + H2O2(18) <=> O2(2) + H2O(8)',
#   'rate-constant': {'A': 843000000000.0, 'b': 0.0, 'Ea': 3.97},
#   'note': 'Reaction index: Chemkin #32; RMG #29\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: H2O2(18), O2(2); O(5), H2O(8);'},
#  {'equation': 'O(5) + OH(15) + M <=> HO2(17) + M',
#   'type': 'three-body',
#   'rate-constant': {'A': 1000000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #33; RMG #30\nLibrary reaction: BurkeH2O2inN2\nFlux pairs: O(5), HO2(17); OH(15), HO2(17);'},
#  {'equation': 'O(5) + C2H4(11) <=> HCO(20) + CH3(19)',
#   'rate-constant': {'A': 5.878095e+17, 'b': -1.717, 'Ea': 2.893},
#   'note': 'Reaction index: Chemkin #34; RMG #31\nLibrary reaction: C2H4+O_Klipp2017\nFlux pairs: C2H4(11), HCO(20); O(5), CH3(19);'},
#  {'equation': 'O(5) + C2H4(11) <=> H(14) + CH3CO(21)',
#   'rate-constant': {'A': 8658438000000.0, 'b': -0.484, 'Ea': 1.958},
#   'note': 'Reaction index: Chemkin #35; RMG #32\nLibrary reaction: C2H4+O_Klipp2017\nFlux pairs: C2H4(11), CH3CO(21); O(5), H(14);'},
#  {'equation': 'O(5) + C2H4(11) <=> H(14) + CH2CHO(22)',
#   'rate-constant': {'A': 9150846000.0, 'b': 0.948, 'Ea': 1.724},
#   'note': 'Reaction index: Chemkin #36; RMG #33\nLibrary reaction: C2H4+O_Klipp2017\nFlux pairs: C2H4(11), CH2CHO(22); O(5), H(14);'},
#  {'equation': 'O(5) + C2H4(11) <=> OH(15) + C2H3(23)',
#   'rate-constant': {'A': 10000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #37; RMG #34\nLibrary reaction: C2H4+O_Klipp2017\nFlux pairs: C2H4(11), C2H3(23); O(5), OH(15);'},
#  {'equation': 'O(5) + C2H4(11) <=> CH2(24) + CH2O(9)',
#   'rate-constant': {'A': 5770135.0, 'b': 1.991, 'Ea': 2.86},
#   'note': 'Reaction index: Chemkin #38; RMG #35\nLibrary reaction: C2H4+O_Klipp2017\nFlux pairs: C2H4(11), CH2O(9); O(5), CH2(24);'},
#  {'equation': 'O(5) + C2H4(11) <=> H2(13) + CH2CO(25)',
#   'rate-constant': {'A': 1.124019e+17, 'b': -1.831, 'Ea': 3.18},
#   'note': 'Reaction index: Chemkin #39; RMG #36\nLibrary reaction: C2H4+O_Klipp2017\nFlux pairs: C2H4(11), CH2CO(25); O(5), H2(13);'},
#  {'equation': 'O(5) + C2H4(11) <=> CO(6) + CH4(10)',
#   'rate-constant': {'A': 10000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #40; RMG #37\nLibrary reaction: C2H4+O_Klipp2017\nFlux pairs: C2H4(11), CO(6); O(5), CH4(10);'},
#  {'equation': 'O(5) + C2H4(11) <=> H2O(8) + C2H2(26)',
#   'rate-constant': {'A': 10000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #41; RMG #38\nLibrary reaction: C2H4+O_Klipp2017\nFlux pairs: C2H4(11), C2H2(26); O(5), H2O(8);'},
#  {'equation': 'O(5) + CO(6) (+M) <=> CO2(7) (+M)',
#   'type': 'falloff',
#   'low-P-rate-constant': {'A': 1.4e+24, 'b': -2.79, 'Ea': 4.191},
#   'high-P-rate-constant': {'A': 18000000000.0, 'b': 0.0, 'Ea': 2.384},
#   'Troe': {'A': 1.0, 'T3': 1e-30, 'T1': 1e+30, 'T2': 1e+30},
#   'efficiencies': {'H2(13)': 2.5, 'CO(6)': 1.9, 'CO2(7)': 3.8, 'H2O(8)': 12.0},
#   'note': 'Reaction index: Chemkin #42; RMG #39\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: O(5), CO2(7); CO(6), CO2(7);'},
#  {'equation': 'OH(15) + CO(6) <=> H(14) + CO2(7)',
#   'type': 'pressure-dependent-Arrhenius',
#   'rate-constants': [{'P': '0.01315 atm',
#     'A': 210000.0,
#     'b': 1.9,
#     'Ea': -1.064},
#    {'P': '0.1315 atm', 'A': 250000.0, 'b': 1.88, 'Ea': -1.043},
#    {'P': '1.315 atm', 'A': 870000.0, 'b': 1.73, 'Ea': -0.685},
#    {'P': '13.158 atm', 'A': 6800000.0, 'b': 1.48, 'Ea': 0.048},
#    {'P': '131.58 atm', 'A': 23000000.0, 'b': 1.35, 'Ea': 0.974}],
#   'note': 'Reaction index: Chemkin #43; RMG #40\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CO(6), CO2(7); OH(15), H(14);'},
#  {'equation': 'HO2(17) + CO(6) <=> OH(15) + CO2(7)',
#   'rate-constant': {'A': 160000.0, 'b': 2.18, 'Ea': 17.943},
#   'note': 'Reaction index: Chemkin #44; RMG #42\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CO(6), CO2(7); HO2(17), OH(15);'},
#  {'equation': 'O2(2) + CO(6) <=> O(5) + CO2(7)',
#   'rate-constant': {'A': 4700000000000.0, 'b': 0.0, 'Ea': 60.5},
#   'note': 'Reaction index: Chemkin #45; RMG #43\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CO(6), CO2(7); O2(2), O(5);'},
#  {'equation': 'H2O2(18) + CO(6) <=> OH(15) + HOCO(27)',
#   'rate-constant': {'A': 36000.0, 'b': 2.5, 'Ea': 28.66},
#   'note': 'Reaction index: Chemkin #46; RMG #44\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CO(6), HOCO(27); H2O2(18), OH(15);'},
#  {'equation': 'H(14) + HOCO(27) <=> H2(13) + CO2(7)',
#   'rate-constant': {'A': 3.1e+17, 'b': -1.347, 'Ea': 0.555},
#   'note': 'Reaction index: Chemkin #47; RMG #46\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: HOCO(27), CO2(7); H(14), H2(13);'},
#  {'equation': 'H(14) + HOCO(27) <=> H2O(8) + CO(6)',
#   'rate-constant': {'A': 6000000000000000.0, 'b': -0.525, 'Ea': 2.125},
#   'note': 'Reaction index: Chemkin #48; RMG #47\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: HOCO(27), CO(6); H(14), H2O(8);'},
#  {'equation': 'O(5) + HOCO(27) <=> OH(15) + CO2(7)',
#   'rate-constant': {'A': 9000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #49; RMG #48\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: HOCO(27), CO2(7); O(5), OH(15);'},
#  {'equation': 'OH(15) + HOCO(27) <=> H2O(8) + CO2(7)',
#   'duplicate': True,
#   'rate-constant': {'A': 4600000000000.0, 'b': 0.0, 'Ea': -0.089},
#   'note': 'Reaction index: Chemkin #50; RMG #49\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'OH(15) + HOCO(27) <=> H2O(8) + CO2(7)',
#   'duplicate': True,
#   'rate-constant': {'A': 9500000.0, 'b': 2.0, 'Ea': -0.089},
#   'note': 'Reaction index: Chemkin #51; RMG #49\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'HO2(17) + HOCO(27) <=> H2O2(18) + CO2(7)',
#   'rate-constant': {'A': 40000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #52; RMG #50\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: HOCO(27), CO2(7); HO2(17), H2O2(18);'},
#  {'equation': 'O2(2) + HOCO(27) <=> HO2(17) + CO2(7)',
#   'rate-constant': {'A': 4000000000.0, 'b': 1.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #53; RMG #51\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: HOCO(27), CO2(7); O2(2), HO2(17);'},
#  {'equation': 'H(14) + CH2O(9) <=> H(14) + H2(13) + CO(6)',
#   'type': 'pressure-dependent-Arrhenius',
#   'rate-constants': [{'P': '0.04 atm',
#     'A': 720000000.0,
#     'b': 1.903,
#     'Ea': 11.733},
#    {'P': '1.0 atm', 'A': 51100000.0, 'b': 2.182, 'Ea': 11.524},
#    {'P': '10.0 atm', 'A': 1160000000.0, 'b': 1.812, 'Ea': 13.163}],
#   'note': 'Reaction index: Chemkin #54; RMG #54\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2O(9), CO(6); H(14), H(14); H(14), H2(13);'},
#  {'equation': 'H(14) + CH2O(9) <=> H2(13) + HCO(20)',
#   'type': 'pressure-dependent-Arrhenius',
#   'rate-constants': [{'P': '0.04 atm',
#     'A': 7.435e+23,
#     'b': -2.732,
#     'Ea': 16.379},
#    {'P': '0.04 atm', 'A': 20980000000.0, 'b': 1.057, 'Ea': 3.72},
#    {'P': '1.0 atm', 'A': 1.357e+23, 'b': -2.355, 'Ea': 17.519},
#    {'P': '1.0 atm', 'A': 1639000000000000.0, 'b': -0.444, 'Ea': 5.682},
#    {'P': '10.0 atm', 'A': 7.314e+23, 'b': -2.665, 'Ea': 17.635},
#    {'P': '10.0 atm', 'A': 4189000000.0, 'b': 1.294, 'Ea': 3.591}],
#   'note': 'Reaction index: Chemkin #55; RMG #55\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2O(9), HCO(20); H(14), H2(13);'},
#  {'equation': 'O(5) + CH2O(9) <=> H(14) + OH(15) + CO(6)',
#   'rate-constant': {'A': 2.5141e+21, 'b': -1.903, 'Ea': 22.674},
#   'note': 'Reaction index: Chemkin #56; RMG #56\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2O(9), CO(6); O(5), H(14); O(5), OH(15);'},
#  {'equation': 'O(5) + CH2O(9) <=> OH(15) + HCO(20)',
#   'duplicate': True,
#   'rate-constant': {'A': 5.634e+31, 'b': -5.189, 'Ea': 19.968},
#   'note': 'Reaction index: Chemkin #57; RMG #57\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'O(5) + CH2O(9) <=> OH(15) + HCO(20)',
#   'duplicate': True,
#   'rate-constant': {'A': 1358000000000000.0, 'b': -0.53, 'Ea': 4.011},
#   'note': 'Reaction index: Chemkin #58; RMG #57\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'O2(2) + CH2O(9) <=> HO2(17) + HCO(20)',
#   'duplicate': True,
#   'rate-constant': {'A': 240000.0, 'b': 2.5, 'Ea': 36.461},
#   'note': 'Reaction index: Chemkin #59; RMG #58\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'O2(2) + CH2O(9) <=> HO2(17) + HCO(20)',
#   'duplicate': True,
#   'rate-constant': {'A': -1437000000000000.0, 'b': 0.027, 'Ea': 56.388},
#   'negative-A': True,
#   'note': 'Reaction index: Chemkin #60; RMG #58\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'O2(2) + CH2O(9) <=> H(14) + HO2(17) + CO(6)',
#   'rate-constant': {'A': 1437000000000000.0, 'b': 0.027, 'Ea': 56.388},
#   'note': 'Reaction index: Chemkin #61; RMG #59\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2O(9), CO(6); O2(2), H(14); O2(2), HO2(17);'},
#  {'equation': 'OH(15) + CH2O(9) <=> H(14) + H2O(8) + CO(6)',
#   'type': 'pressure-dependent-Arrhenius',
#   'rate-constants': [{'P': '0.04 atm',
#     'A': 70300000000.0,
#     'b': 0.911,
#     'Ea': 8.646},
#    {'P': '1.0 atm', 'A': 72400000000.0, 'b': 0.892, 'Ea': 9.31},
#    {'P': '10.0 atm', 'A': 83700000000.0, 'b': 0.879, 'Ea': 9.843}],
#   'note': 'Reaction index: Chemkin #62; RMG #60\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2O(9), CO(6); OH(15), H(14); OH(15), H2O(8);'},
#  {'equation': 'OH(15) + CH2O(9) <=> H2O(8) + HCO(20)',
#   'type': 'pressure-dependent-Arrhenius',
#   'rate-constants': [{'P': '0.04 atm',
#     'A': 3559000000.0,
#     'b': 1.167,
#     'Ea': -0.206},
#    {'P': '1.0 atm', 'A': 1854000000.0, 'b': 1.256, 'Ea': -0.302},
#    {'P': '10.0 atm', 'A': 1070000000.0, 'b': 1.33, 'Ea': -0.392}],
#   'note': 'Reaction index: Chemkin #63; RMG #61\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2O(9), HCO(20); OH(15), H2O(8);'},
#  {'equation': 'HO2(17) + CH2O(9) <=> H2O2(18) + HCO(20)',
#   'duplicate': True,
#   'rate-constant': {'A': 41000.0, 'b': 2.5, 'Ea': 10.206},
#   'note': 'Reaction index: Chemkin #64; RMG #62\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'HO2(17) + CH2O(9) <=> H2O2(18) + HCO(20)',
#   'duplicate': True,
#   'rate-constant': {'A': -245400000000000.0, 'b': 0.027, 'Ea': 30.133},
#   'negative-A': True,
#   'note': 'Reaction index: Chemkin #65; RMG #62\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'HO2(17) + CH2O(9) <=> H(14) + H2O2(18) + CO(6)',
#   'rate-constant': {'A': 245430000000000.0, 'b': 0.027, 'Ea': 30.12},
#   'note': 'Reaction index: Chemkin #66; RMG #63\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2O(9), CO(6); HO2(17), H(14); HO2(17), H2O2(18);'},
#  {'equation': 'CH2O(9) + CH3(19) <=> HCO(20) + CH4(10)',
#   'duplicate': True,
#   'rate-constant': {'A': 32.0, 'b': 3.36, 'Ea': 4.31},
#   'note': 'Reaction index: Chemkin #67; RMG #64\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'CH2O(9) + CH3(19) <=> HCO(20) + CH4(10)',
#   'duplicate': True,
#   'rate-constant': {'A': -191600000000.0, 'b': 0.887, 'Ea': 24.237},
#   'negative-A': True,
#   'note': 'Reaction index: Chemkin #68; RMG #64\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'CH2O(9) + CH3(19) <=> H(14) + CO(6) + CH4(10)',
#   'rate-constant': {'A': 191550000000.0, 'b': 0.887, 'Ea': 24.224},
#   'note': 'Reaction index: Chemkin #69; RMG #65\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2O(9), CO(6); CH3(19), H(14); CH3(19), CH4(10);'},
#  {'equation': 'H(14) + HCO(20) <=> H2(13) + CO(6)',
#   'rate-constant': {'A': 110000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #70; RMG #67\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: HCO(20), CO(6); H(14), H2(13);'},
#  {'equation': 'O(5) + HCO(20) <=> OH(15) + CO(6)',
#   'rate-constant': {'A': 30000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #71; RMG #68\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: HCO(20), CO(6); O(5), OH(15);'},
#  {'equation': 'O(5) + HCO(20) <=> H(14) + CO2(7)',
#   'rate-constant': {'A': 30000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #72; RMG #69\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: HCO(20), CO2(7); O(5), H(14);'},
#  {'equation': 'OH(15) + HCO(20) <=> H2O(8) + CO(6)',
#   'rate-constant': {'A': 110000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #73; RMG #70\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: HCO(20), CO(6); OH(15), H2O(8);'},
#  {'equation': 'O2(2) + HCO(20) <=> HO2(17) + CO(6)',
#   'rate-constant': {'A': 6900000.0, 'b': 1.9, 'Ea': -1.369},
#   'note': 'Reaction index: Chemkin #74; RMG #71\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: HCO(20), CO(6); O2(2), HO2(17);'},
#  {'equation': 'HO2(17) + HCO(20) <=> H(14) + OH(15) + CO2(7)',
#   'rate-constant': {'A': 30000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #75; RMG #72\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: HCO(20), CO2(7); HO2(17), H(14); HO2(17), OH(15);'},
#  {'equation': 'HCO(20) + HCO(20) <=> CO(6) + CH2O(9)',
#   'rate-constant': {'A': 27000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #76; RMG #73\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: HCO(20), CH2O(9); HCO(20), CO(6);'},
#  {'equation': 'H(14) + CH4(10) <=> H2(13) + CH3(19)',
#   'rate-constant': {'A': 4100.0, 'b': 3.156, 'Ea': 8.755},
#   'note': 'Reaction index: Chemkin #77; RMG #75\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH4(10), CH3(19); H(14), H2(13);'},
#  {'equation': 'O(5) + CH4(10) <=> OH(15) + CH3(19)',
#   'rate-constant': {'A': 440000.0, 'b': 2.5, 'Ea': 6.577},
#   'note': 'Reaction index: Chemkin #78; RMG #76\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH4(10), CH3(19); O(5), OH(15);'},
#  {'equation': 'OH(15) + CH4(10) <=> H2O(8) + CH3(19)',
#   'rate-constant': {'A': 1000000.0, 'b': 2.182, 'Ea': 2.506},
#   'note': 'Reaction index: Chemkin #79; RMG #77\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH4(10), CH3(19); OH(15), H2O(8);'},
#  {'equation': 'HO2(17) + CH4(10) <=> H2O2(18) + CH3(19)',
#   'rate-constant': {'A': 47000.0, 'b': 2.5, 'Ea': 21.0},
#   'note': 'Reaction index: Chemkin #80; RMG #78\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH4(10), CH3(19); HO2(17), H2O2(18);'},
#  {'equation': 'O2(2) + CH4(10) <=> HO2(17) + CH3(19)',
#   'rate-constant': {'A': 203000.0, 'b': 2.745, 'Ea': 51.714},
#   'note': 'Reaction index: Chemkin #81; RMG #79\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH4(10), CH3(19); O2(2), HO2(17);'},
#  {'equation': 'CH2(24) + CH4(10) <=> CH3(19) + CH3(19)',
#   'duplicate': True,
#   'rate-constant': {'A': 4300000000000.0, 'b': 0.0, 'Ea': 10.03},
#   'note': 'Reaction index: Chemkin #82; RMG #80\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'CH2(24) + CH4(10) <=> CH3(19) + CH3(19)',
#   'duplicate': True,
#   'rate-constant': {'A': 43000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #83; RMG #80\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'CH(3) + CH4(10) <=> H(14) + C2H4(11)',
#   'rate-constant': {'A': 30000000000000.0, 'b': 0.0, 'Ea': -0.4},
#   'note': 'Reaction index: Chemkin #84; RMG #81\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH4(10), C2H4(11); CH(3), H(14);'},
#  {'equation': 'CH3(19) + M <=> H2(13) + CH(3) + M',
#   'type': 'three-body',
#   'rate-constant': {'A': 3100000000000000.0, 'b': 0.0, 'Ea': 80.871},
#   'note': 'Reaction index: Chemkin #85; RMG #82\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3(19), H2(13); CH3(19), CH(3);'},
#  {'equation': 'CH3(19) + M <=> H(14) + CH2(24) + M',
#   'type': 'three-body',
#   'rate-constant': {'A': 2200000000000000.0, 'b': 0.0, 'Ea': 82.659},
#   'note': 'Reaction index: Chemkin #86; RMG #83\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3(19), H(14); CH3(19), CH2(24);'},
#  {'equation': 'H2(13) + CH2(24) <=> H(14) + CH3(19)',
#   'duplicate': True,
#   'rate-constant': {'A': 440000.0, 'b': 2.39, 'Ea': 7.35},
#   'note': 'Reaction index: Chemkin #87; RMG #84\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'H2(13) + CH2(24) <=> H(14) + CH3(19)',
#   'duplicate': True,
#   'rate-constant': {'A': 72000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #88; RMG #84\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'O(5) + CH3(19) <=> H(14) + CH2O(9)',
#   'rate-constant': {'A': 69000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #89; RMG #85\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3(19), CH2O(9); O(5), H(14);'},
#  {'equation': 'O(5) + CH3(19) <=> H(14) + H2(13) + CO(6)',
#   'rate-constant': {'A': 15000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #90; RMG #86\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3(19), CO(6); O(5), H(14); O(5), H2(13);'},
#  {'equation': 'OH(15) + CH3(19) <=> H2O(8) + CH2(24)',
#   'rate-constant': {'A': 43000.0, 'b': 2.568, 'Ea': 3.997},
#   'note': 'Reaction index: Chemkin #91; RMG #87\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3(19), CH2(24); OH(15), H2O(8);'},
#  {'equation': 'OH(15) + CH3(19) <=> H2O(8) + CH2(S)(29)',
#   'type': 'pressure-dependent-Arrhenius',
#   'rate-constants': [{'P': '0.001316 atm',
#     'A': 110000000000000.0,
#     'b': -0.458,
#     'Ea': -0.496},
#    {'P': '0.013158 atm', 'A': 220000000000000.0, 'b': -0.538, 'Ea': -0.22},
#    {'P': '0.131579 atm', 'A': 1200000000000000.0, 'b': -0.727, 'Ea': 0.6},
#    {'P': '1.31579 atm', 'A': 4300000000000000.0, 'b': -0.86, 'Ea': 1.888},
#    {'P': '13.1579 atm', 'A': 440000000000000.0, 'b': -0.539, 'Ea': 2.932},
#    {'P': '131.579 atm', 'A': 61000000000.0, 'b': 0.596, 'Ea': 2.923}],
#   'note': 'Reaction index: Chemkin #92; RMG #89\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3(19), CH2(S)(29); OH(15), H2O(8);'},
#  {'equation': 'OH(15) + CH3(19) <=> H2(13) + CH2O(9)',
#   'type': 'pressure-dependent-Arrhenius',
#   'rate-constants': [{'P': '0.001316 atm',
#     'A': 3900000000.0,
#     'b': 0.254,
#     'Ea': -1.221},
#    {'P': '0.013158 atm', 'A': 20000000000.0, 'b': 0.06, 'Ea': -0.624},
#    {'P': '0.131579 atm', 'A': 280000000000.0, 'b': -0.25, 'Ea': 0.498},
#    {'P': '1.31579 atm', 'A': 3600000000000.0, 'b': -0.532, 'Ea': 2.042},
#    {'P': '13.1579 atm', 'A': 2200000000000.0, 'b': -0.432, 'Ea': 3.415},
#    {'P': '131.579 atm', 'A': 2400000000.0, 'b': 0.453, 'Ea': 3.791}],
#   'note': 'Reaction index: Chemkin #93; RMG #90\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3(19), CH2O(9); OH(15), H2(13);'},
#  {'equation': 'OH(15) + CH3(19) <=> H(14) + CH2OH(30)',
#   'type': 'pressure-dependent-Arrhenius',
#   'rate-constants': [{'P': '0.001316 atm',
#     'A': 8400000000.0,
#     'b': 0.963,
#     'Ea': 3.23},
#    {'P': '0.013158 atm', 'A': 8400000000.0, 'b': 0.963, 'Ea': 3.23},
#    {'P': '0.131579 atm', 'A': 10000000000.0, 'b': 0.942, 'Ea': 3.295},
#    {'P': '1.31579 atm', 'A': 56000000000.0, 'b': 0.74, 'Ea': 3.971},
#    {'P': '13.1579 atm', 'A': 550000000000.0, 'b': 0.486, 'Ea': 5.443},
#    {'P': '131.579 atm', 'A': 25000000000.0, 'b': 0.909, 'Ea': 6.402}],
#   'note': 'Reaction index: Chemkin #94; RMG #91\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3(19), CH2OH(30); OH(15), H(14);'},
#  {'equation': 'OH(15) + CH3(19) <=> H(14) + CH3O(31)',
#   'type': 'pressure-dependent-Arrhenius',
#   'rate-constants': [{'P': '0.001316 atm',
#     'A': 790000000.0,
#     'b': 1.065,
#     'Ea': 11.859},
#    {'P': '0.013158 atm', 'A': 790000000.0, 'b': 1.065, 'Ea': 11.859},
#    {'P': '0.131579 atm', 'A': 790000000.0, 'b': 1.065, 'Ea': 11.859},
#    {'P': '1.31579 atm', 'A': 790000000.0, 'b': 1.065, 'Ea': 11.859},
#    {'P': '13.1579 atm', 'A': 1000000000.0, 'b': 1.034, 'Ea': 11.97},
#    {'P': '131.579 atm', 'A': 3100000000.0, 'b': 0.922, 'Ea': 12.981}],
#   'note': 'Reaction index: Chemkin #95; RMG #92\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3(19), CH3O(31); OH(15), H(14);'},
#  {'equation': 'OH(15) + CH3(19) <=> H2(13) + HCOH(32)',
#   'type': 'pressure-dependent-Arrhenius',
#   'rate-constants': [{'P': '0.001316 atm',
#     'A': 1200000000.0,
#     'b': 0.83,
#     'Ea': -2.323},
#    {'P': '0.013158 atm', 'A': 6400000000.0, 'b': 0.633, 'Ea': -1.701},
#    {'P': '0.131579 atm', 'A': 80000000000.0, 'b': 0.34, 'Ea': -0.565},
#    {'P': '1.31579 atm', 'A': 650000000000.0, 'b': 0.112, 'Ea': 0.932},
#    {'P': '13.1579 atm', 'A': 210000000000.0, 'b': 0.295, 'Ea': 2.2},
#    {'P': '131.579 atm', 'A': 94000000.0, 'b': 1.286, 'Ea': 2.424}],
#   'note': 'Reaction index: Chemkin #96; RMG #93\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3(19), HCOH(32); OH(15), H2(13);'},
#  {'equation': 'HO2(17) + CH3(19) <=> OH(15) + CH3O(31)',
#   'rate-constant': {'A': 1000000000000.0, 'b': 0.269, 'Ea': 0.688},
#   'note': 'Reaction index: Chemkin #97; RMG #94\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3(19), CH3O(31); HO2(17), OH(15);'},
#  {'equation': 'O2(2) + CH3(19) <=> O(5) + CH3O(31)',
#   'rate-constant': {'A': 7500000000000.0, 'b': 0.0, 'Ea': 28.297},
#   'note': 'Reaction index: Chemkin #98; RMG #95\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3(19), CH3O(31); O2(2), O(5);'},
#  {'equation': 'O2(2) + CH3(19) <=> OH(15) + CH2O(9)',
#   'rate-constant': {'A': 190000000000.0, 'b': 0.0, 'Ea': 9.842},
#   'note': 'Reaction index: Chemkin #99; RMG #96\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3(19), CH2O(9); O2(2), OH(15);'},
#  {'equation': 'O2(2) + CH3(19) <=> CH3OO(33)',
#   'duplicate': True,
#   'type': 'pressure-dependent-Arrhenius',
#   'rate-constants': [{'P': '1.0 atm', 'A': 5e+22, 'b': -3.85, 'Ea': 2.0},
#    {'P': '10.0 atm', 'A': 3.35e+21, 'b': -3.2, 'Ea': 2.3},
#    {'P': '20.0 atm', 'A': 3.25e+29, 'b': -5.6, 'Ea': 6.85},
#    {'P': '50.0 atm', 'A': 2.83e+18, 'b': -2.2, 'Ea': 1.4},
#    {'P': '100.0 atm', 'A': 1.05e+19, 'b': -2.3, 'Ea': 1.8}],
#   'note': 'Reaction index: Chemkin #100; RMG #97\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'O2(2) + CH3(19) <=> CH3OO(33)',
#   'duplicate': True,
#   'type': 'pressure-dependent-Arrhenius',
#   'rate-constants': [{'P': '20.0 atm', 'A': 4.1e+20, 'b': -2.94, 'Ea': 1.9},
#    {'P': '50.0 atm', 'A': 5.6e+28, 'b': -5.25, 'Ea': 6.85},
#    {'P': '100.0 atm', 'A': 4.1e+30, 'b': -5.7, 'Ea': 8.75}],
#   'note': 'Reaction index: Chemkin #101; RMG #97\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'HCO(20) + CH3(19) <=> CO(6) + CH4(10)',
#   'type': 'pressure-dependent-Arrhenius',
#   'rate-constants': [{'P': '0.05 atm', 'A': 2.9e+18, 'b': -1.84, 'Ea': 2.134},
#    {'P': '0.1 atm', 'A': 8.7e+18, 'b': -1.97, 'Ea': 2.684},
#    {'P': '1.0 atm', 'A': 1.8e+20, 'b': -2.3, 'Ea': 4.781},
#    {'P': '10.0 atm', 'A': 1.1e+21, 'b': -2.45, 'Ea': 7.417}],
#   'note': 'Reaction index: Chemkin #102; RMG #98\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: HCO(20), CO(6); CH3(19), CH4(10);'},
#  {'equation': 'HCO(20) + CH3(19) <=> H2(13) + CH2CO(25)',
#   'type': 'pressure-dependent-Arrhenius',
#   'rate-constants': [{'P': '0.05 atm',
#     'A': 6100000.0,
#     'b': 1.24,
#     'Ea': -1.733},
#    {'P': '0.1 atm', 'A': 11000000.0, 'b': 1.18, 'Ea': -1.303},
#    {'P': '1.0 atm', 'A': 490000000.0, 'b': 0.75, 'Ea': 0.842},
#    {'P': '10.0 atm', 'A': 160000000000.0, 'b': 0.109, 'Ea': 4.387}],
#   'note': 'Reaction index: Chemkin #103; RMG #99\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: HCO(20), CH2CO(25); CH3(19), H2(13);'},
#  {'equation': 'CH3(19) + CH3(19) <=> H(14) + C2H5(34)',
#   'rate-constant': {'A': 54000000000000.0, 'b': 0.0, 'Ea': 16.055},
#   'note': 'Reaction index: Chemkin #104; RMG #100\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3(19), C2H5(34); CH3(19), H(14);'},
#  {'equation': 'CH2(24) + CH3(19) <=> H(14) + C2H4(11)',
#   'duplicate': True,
#   'rate-constant': {'A': 1200000000000000.0, 'b': -0.343, 'Ea': 0.153},
#   'note': 'Reaction index: Chemkin #105; RMG #101\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'CH2(24) + CH3(19) <=> H(14) + C2H4(11)',
#   'duplicate': True,
#   'rate-constant': {'A': 20000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #106; RMG #101\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'CH(3) + CH3(19) <=> H(14) + C2H3(23)',
#   'rate-constant': {'A': 30000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #107; RMG #102\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3(19), C2H3(23); CH(3), H(14);'},
#  {'equation': 'C(35) + CH3(19) <=> H(14) + C2H2(26)',
#   'rate-constant': {'A': 50000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #108; RMG #103\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3(19), C2H2(26); C(35), H(14);'},
#  {'equation': 'CH2(24) + M <=> H(14) + CH(3) + M',
#   'type': 'three-body',
#   'rate-constant': {'A': 5600000000000000.0, 'b': 0.0, 'Ea': 89.0},
#   'note': 'Reaction index: Chemkin #109; RMG #104\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2(24), H(14); CH2(24), CH(3);'},
#  {'equation': 'CH2(24) + M <=> H2(13) + C(35) + M',
#   'type': 'three-body',
#   'rate-constant': {'A': 5800000000000.0, 'b': 0.5, 'Ea': 68.5},
#   'note': 'Reaction index: Chemkin #110; RMG #105\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2(24), H2(13); CH2(24), C(35);'},
#  {'equation': 'H(14) + CH2(24) <=> H2(13) + CH(3)',
#   'duplicate': True,
#   'rate-constant': {'A': 120000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #111; RMG #106\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'H(14) + CH2(24) <=> H2(13) + CH(3)',
#   'duplicate': True,
#   'rate-constant': {'A': 30000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #112; RMG #106\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'O(5) + CH2(24) <=> H(14) + H(14) + CO(6)',
#   'duplicate': True,
#   'rate-constant': {'A': 120000000000000.0, 'b': 0.0, 'Ea': 0.536},
#   'note': 'Reaction index: Chemkin #113; RMG #107\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'O(5) + CH2(24) <=> H(14) + H(14) + CO(6)',
#   'duplicate': True,
#   'rate-constant': {'A': 30000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #114; RMG #107\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'O(5) + CH2(24) <=> H2(13) + CO(6)',
#   'rate-constant': {'A': 80000000000000.0, 'b': 0.0, 'Ea': 0.536},
#   'note': 'Reaction index: Chemkin #115; RMG #108\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2(24), CO(6); O(5), H2(13);'},
#  {'equation': 'OH(15) + CH2(24) <=> H(14) + CH2O(9)',
#   'duplicate': True,
#   'rate-constant': {'A': 28000000000000.0, 'b': 0.123, 'Ea': 0.161},
#   'note': 'Reaction index: Chemkin #116; RMG #109\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'OH(15) + CH2(24) <=> H(14) + CH2O(9)',
#   'duplicate': True,
#   'rate-constant': {'A': 30000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #117; RMG #109\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'OH(15) + CH2(24) <=> H2O(8) + CH(3)',
#   'rate-constant': {'A': 860000.0, 'b': 2.019, 'Ea': 6.776},
#   'note': 'Reaction index: Chemkin #118; RMG #110\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2(24), CH(3); OH(15), H2O(8);'},
#  {'equation': 'O2(2) + CH2(24) <=> H(14) + H(14) + CO2(7)',
#   'rate-constant': {'A': 2100000000.0, 'b': 0.993, 'Ea': -0.269},
#   'note': 'Reaction index: Chemkin #119; RMG #111\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2(24), CO2(7); O2(2), H(14); O2(2), H(14);'},
#  {'equation': 'O2(2) + CH2(24) <=> O(5) + CH2O(9)',
#   'rate-constant': {'A': 1300000.0, 'b': 2.42, 'Ea': 1.604},
#   'note': 'Reaction index: Chemkin #120; RMG #112\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2(24), CH2O(9); O2(2), O(5);'},
#  {'equation': 'CO2(7) + CH2(24) <=> CO(6) + CH2O(9)',
#   'duplicate': True,
#   'rate-constant': {'A': 100000000000.0, 'b': 0.0, 'Ea': 1.0},
#   'note': 'Reaction index: Chemkin #121; RMG #113\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'CO2(7) + CH2(24) <=> CO(6) + CH2O(9)',
#   'duplicate': True,
#   'rate-constant': {'A': 11000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #122; RMG #113\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'CH2(24) + CH2(24) <=> H(14) + H(14) + C2H2(26)',
#   'rate-constant': {'A': 70000000000000.0, 'b': 0.002, 'Ea': 0.008},
#   'note': 'Reaction index: Chemkin #123; RMG #114\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2(24), C2H2(26); CH2(24), H(14); CH2(24), H(14);'},
#  {'equation': 'CH2(24) + CH2(24) <=> H2(13) + C2H2(26)',
#   'rate-constant': {'A': 18000000000000.0, 'b': 0.002, 'Ea': 0.008},
#   'note': 'Reaction index: Chemkin #124; RMG #115\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2(24), C2H2(26); CH2(24), H2(13);'},
#  {'equation': 'CH(3) + CH2(24) <=> H(14) + C2H2(26)',
#   'rate-constant': {'A': 40000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #125; RMG #116\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2(24), C2H2(26); CH(3), H(14);'},
#  {'equation': 'C(35) + CH2(24) <=> H(14) + C2H(4)',
#   'rate-constant': {'A': 50000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #126; RMG #117\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2(24), C2H(4); C(35), H(14);'},
#  {'equation': 'N2 + CH2(S)(29) <=> N2 + CH2(24)',
#   'rate-constant': {'A': 13000000000000.0, 'b': 0.0, 'Ea': 0.43},
#   'note': 'Reaction index: Chemkin #127; RMG #118\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2(S)(29), CH2(24); N2, N2;'},
#  {'equation': 'Ar + CH2(S)(29) <=> Ar + CH2(24)',
#   'rate-constant': {'A': 15000000000000.0, 'b': 0.0, 'Ea': 0.884},
#   'note': 'Reaction index: Chemkin #128; RMG #119\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2(S)(29), CH2(24); Ar, Ar;'},
#  {'equation': 'H(14) + CH2(S)(29) <=> H(14) + CH2(24)',
#   'rate-constant': {'A': 200000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #129; RMG #120\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2(S)(29), CH2(24); H(14), H(14);'},
#  {'equation': 'O2(2) + CH2(S)(29) <=> O2(2) + CH2(24)',
#   'rate-constant': {'A': 31000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #130; RMG #121\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2(S)(29), CH2(24); O2(2), O2(2);'},
#  {'equation': 'H2O(8) + CH2(S)(29) <=> H2O(8) + CH2(24)',
#   'rate-constant': {'A': 30000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #131; RMG #122\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2(S)(29), CH2(24); H2O(8), H2O(8);'},
#  {'equation': 'H(14) + CH(3) <=> H2(13) + C(35)',
#   'rate-constant': {'A': 120000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #132; RMG #123\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH(3), C(35); H(14), H2(13);'},
#  {'equation': 'O(5) + CH(3) <=> H(14) + CO(6)',
#   'rate-constant': {'A': 57000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #133; RMG #124\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH(3), CO(6); O(5), H(14);'},
#  {'equation': 'OH(15) + CH(3) <=> H(14) + HCO(20)',
#   'duplicate': True,
#   'rate-constant': {'A': 30000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #134; RMG #125\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'OH(15) + CH(3) <=> H(14) + HCO(20)',
#   'duplicate': True,
#   'rate-constant': {'A': -1.796e+23, 'b': -2.473, 'Ea': 19.927},
#   'negative-A': True,
#   'note': 'Reaction index: Chemkin #135; RMG #125\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'OH(15) + CH(3) <=> H(14) + H(14) + CO(6)',
#   'rate-constant': {'A': 1.796e+23, 'b': -2.473, 'Ea': 19.927},
#   'note': 'Reaction index: Chemkin #136; RMG #126\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH(3), CO(6); OH(15), H(14); OH(15), H(14);'},
#  {'equation': 'OH(15) + CH(3) <=> H2O(8) + C(35)',
#   'rate-constant': {'A': 40000000.0, 'b': 2.0, 'Ea': 3.0},
#   'note': 'Reaction index: Chemkin #137; RMG #127\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH(3), C(35); OH(15), H2O(8);'},
#  {'equation': 'O2(2) + CH(3) <=> O(5) + HCO(20)',
#   'duplicate': True,
#   'rate-constant': {'A': 33000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #138; RMG #128\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'O2(2) + CH(3) <=> O(5) + HCO(20)',
#   'duplicate': True,
#   'rate-constant': {'A': -1.975e+23, 'b': -2.473, 'Ea': 19.927},
#   'negative-A': True,
#   'note': 'Reaction index: Chemkin #139; RMG #128\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'O2(2) + CH(3) <=> O(5) + H(14) + CO(6)',
#   'rate-constant': {'A': 1.975e+23, 'b': -2.473, 'Ea': 19.927},
#   'note': 'Reaction index: Chemkin #140; RMG #129\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH(3), CO(6); O2(2), H(14); O2(2), O(5);'},
#  {'equation': 'H2O(8) + CH(3) <=> H(14) + CH2O(9)',
#   'rate-constant': {'A': 850000000.0, 'b': 1.144, 'Ea': -2.051},
#   'note': 'Reaction index: Chemkin #141; RMG #130\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH(3), CH2O(9); H2O(8), H(14);'},
#  {'equation': 'CO2(7) + CH(3) <=> CO(6) + HCO(20)',
#   'duplicate': True,
#   'rate-constant': {'A': 8800000.0, 'b': 1.75, 'Ea': -1.04},
#   'note': 'Reaction index: Chemkin #142; RMG #131\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'CO2(7) + CH(3) <=> CO(6) + HCO(20)',
#   'duplicate': True,
#   'rate-constant': {'A': -5.268e+16, 'b': -0.723, 'Ea': 18.887},
#   'negative-A': True,
#   'note': 'Reaction index: Chemkin #143; RMG #131\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'CO2(7) + CH(3) <=> H(14) + CO(6) + CO(6)',
#   'rate-constant': {'A': 5.268e+16, 'b': -0.723, 'Ea': 18.887},
#   'note': 'Reaction index: Chemkin #144; RMG #132\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CO2(7), CO(6); CH(3), H(14); CH(3), CO(6);'},
#  {'equation': 'CH(3) + CH2O(9) <=> H(14) + CH2CO(25)',
#   'rate-constant': {'A': 95000000000000.0, 'b': 0.0, 'Ea': -0.517},
#   'note': 'Reaction index: Chemkin #145; RMG #133\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2O(9), CH2CO(25); CH(3), H(14);'},
#  {'equation': 'OH(15) + C(35) <=> H(14) + CO(6)',
#   'rate-constant': {'A': 50000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #146; RMG #134\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: C(35), CO(6); OH(15), H(14);'},
#  {'equation': 'O2(2) + C(35) <=> O(5) + CO(6)',
#   'rate-constant': {'A': 20000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #147; RMG #135\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: C(35), CO(6); O2(2), O(5);'},
#  {'equation': 'H(14) + CH3OH(28) <=> H2(13) + CH2OH(30)',
#   'rate-constant': {'A': 66000.0, 'b': 2.728, 'Ea': 4.449},
#   'note': 'Reaction index: Chemkin #148; RMG #139\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3OH(28), CH2OH(30); H(14), H2(13);'},
#  {'equation': 'H(14) + CH3OH(28) <=> H2(13) + CH3O(31)',
#   'rate-constant': {'A': 41000.0, 'b': 2.658, 'Ea': 9.221},
#   'note': 'Reaction index: Chemkin #149; RMG #140\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3OH(28), CH3O(31); H(14), H2(13);'},
#  {'equation': 'O(5) + CH3OH(28) <=> OH(15) + CH2OH(30)',
#   'rate-constant': {'A': 21000000000000.0, 'b': 0.0, 'Ea': 5.305},
#   'note': 'Reaction index: Chemkin #150; RMG #141\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3OH(28), CH2OH(30); O(5), OH(15);'},
#  {'equation': 'O(5) + CH3OH(28) <=> OH(15) + CH3O(31)',
#   'rate-constant': {'A': 3700000000000.0, 'b': 0.0, 'Ea': 5.305},
#   'note': 'Reaction index: Chemkin #151; RMG #142\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3OH(28), CH3O(31); O(5), OH(15);'},
#  {'equation': 'OH(15) + CH3OH(28) <=> H2O(8) + CH2OH(30)',
#   'rate-constant': {'A': 150000000.0, 'b': 1.443, 'Ea': 0.113},
#   'note': 'Reaction index: Chemkin #152; RMG #143\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3OH(28), CH2OH(30); OH(15), H2O(8);'},
#  {'equation': 'OH(15) + CH3OH(28) <=> H2O(8) + CH3O(31)',
#   'rate-constant': {'A': 27000000.0, 'b': 1.443, 'Ea': 0.113},
#   'note': 'Reaction index: Chemkin #153; RMG #144\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3OH(28), CH3O(31); OH(15), H2O(8);'},
#  {'equation': 'HO2(17) + CH3OH(28) <=> H2O2(18) + CH2OH(30)',
#   'rate-constant': {'A': 0.00035, 'b': 4.85, 'Ea': 10.346},
#   'note': 'Reaction index: Chemkin #154; RMG #145\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3OH(28), CH2OH(30); HO2(17), H2O2(18);'},
#  {'equation': 'HO2(17) + CH3OH(28) <=> H2O2(18) + CH3O(31)',
#   'rate-constant': {'A': 0.0015, 'b': 4.61, 'Ea': 15.828},
#   'note': 'Reaction index: Chemkin #155; RMG #146\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3OH(28), CH3O(31); HO2(17), H2O2(18);'},
#  {'equation': 'O2(2) + CH3OH(28) <=> HO2(17) + CH2OH(30)',
#   'rate-constant': {'A': 360000.0, 'b': 2.27, 'Ea': 42.76},
#   'note': 'Reaction index: Chemkin #156; RMG #147\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3OH(28), CH2OH(30); O2(2), HO2(17);'},
#  {'equation': 'HO2(17) + CH3O(31) <=> O2(2) + CH3OH(28)',
#   'rate-constant': {'A': 140000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #157; RMG #148\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH3O(31), CH3OH(28); HO2(17), O2(2);'},
#  {'equation': 'H(14) + CH2OH(30) <=> H2(13) + CH2O(9)',
#   'rate-constant': {'A': 4000000.0, 'b': 1.86, 'Ea': 0.147},
#   'note': 'Reaction index: Chemkin #158; RMG #150\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2OH(30), CH2O(9); H(14), H2(13);'},
#  {'equation': 'O(5) + CH2OH(30) <=> OH(15) + CH2O(9)',
#   'rate-constant': {'A': 66000000000000.0, 'b': 0.0, 'Ea': -0.693},
#   'note': 'Reaction index: Chemkin #159; RMG #151\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2OH(30), CH2O(9); O(5), OH(15);'},
#  {'equation': 'OH(15) + CH2OH(30) <=> H2O(8) + CH2O(9)',
#   'rate-constant': {'A': 24000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #160; RMG #152\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2OH(30), CH2O(9); OH(15), H2O(8);'},
#  {'equation': 'HO2(17) + CH2OH(30) <=> H2O2(18) + CH2O(9)',
#   'rate-constant': {'A': 12000000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #161; RMG #153\nLibrary reaction: Klippenstein_Glarborg2016\nFlux pairs: CH2OH(30), CH2O(9); HO2(17), H2O2(18);'},
#  {'equation': 'O2(2) + CH2OH(30) <=> HO2(17) + CH2O(9)',
#   'duplicate': True,
#   'rate-constant': {'A': 72000000000000.0, 'b': 0.0, 'Ea': 3.736},
#   'note': 'Reaction index: Chemkin #162; RMG #154\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'O2(2) + CH2OH(30) <=> HO2(17) + CH2O(9)',
#   'duplicate': True,
#   'rate-constant': {'A': 2.9e+16, 'b': -1.5, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #163; RMG #154\nLibrary reaction: Klippenstein_Glarborg2016'},
#  {'equation': 'CH3(19) + CH2OH(30) <=> H2O(8) + C2H4(11)',
#   'type': 'pressure-dependent-Arrhenius',
#   'rate-constants': [{'P': '0.001 atm',
#     'A': 6.3e+24,
#     'b': -3.713,
#     'Ea': 2.798},
#    {'P': '0.01 atm', 'A': 1.2e+25, 'b': -3.787, 'Ea': 3.001},
#    {'P': '0.1 atm', 'A': 3.2e+27, 'b': -4.45, 'Ea': 5.345},
#    {'P': '1.0 atm', 'A': 7.2e+29, 'b': -5.034, 'Ea': 9.245},
# ...
#   'rate-constant': {'A': 110000000000.0, 'b': 0.0, 'Ea0': 8.624, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #967; RMG #4255\nTemplate reaction: H_Abstraction\nFlux pairs: C2H5O(40), C2H6O(55); C7H16(1), C7H15(684);\nEstimated using an average for rate rule [C/H2/NonDeC;O_rad/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(684) + C7H16(1) <=> C7H15(686) + C7H16(1)',
#   'rate-constant': {'A': 0.005147495, 'b': 4.29, 'Ea0': 7.713, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #968; RMG #4267\nTemplate reaction: H_Abstraction\nFlux pairs: C7H16(1), C7H15(686); C7H15(684), C7H16(1);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(684) <=> C7H15(683)',
#   'rate-constant': {'A': 13520000000.0, 'b': 0.88, 'Ea': 38.0},
#   'note': 'Reaction index: Chemkin #969; RMG #4447\nTemplate reaction: intra_H_migration\nFlux pairs: C7H15(684), C7H15(683);\nEstimated using template [R2H_S;C_rad_out_H/NonDeC;Cs_H_out_H/NonDeC] for rate rule [R2H_S;C_rad_out_H/NonDeC;Cs_H_out_H/(NonDeC/Cs)]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 4.0\nfamily: intra_H_migration'},
#  {'equation': 'C7H15(684) + C7H16(1) <=> C7H15(683) + C7H16(1)',
#   'rate-constant': {'A': 0.005147495, 'b': 4.29, 'Ea0': 7.713, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #970; RMG #4452\nTemplate reaction: H_Abstraction\nFlux pairs: C7H16(1), C7H15(683); C7H15(684), C7H16(1);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3O(31) + C7H16(1) <=> CH3OH(28) + C7H15(684)',
#   'rate-constant': {'A': 110000000000.0, 'b': 0.0, 'Ea0': 8.624, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #971; RMG #4507\nTemplate reaction: H_Abstraction\nFlux pairs: CH3O(31), CH3OH(28); C7H16(1), C7H15(684);\nEstimated using an average for rate rule [C/H2/NonDeC;O_rad/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H5O(44) + C7H15(684) <=> C2H4O(43) + C7H16(1)',
#   'rate-constant': {'A': 102600000000000.0, 'b': -0.35, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #972; RMG #4548\nTemplate reaction: Disproportionation\nFrom training reaction 27 used for C_rad/H/NonDeC;C/H2/Nd_Csrad\nExact match found for rate rule [C_rad/H/NonDeC;C/H2/Nd_Csrad]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: Disproportionation'},
#  {'equation': 'C2H5O(56) + C7H15(684) <=> C2H4O(43) + C7H16(1)',
#   'rate-constant': {'A': 633000000000000.0, 'b': -0.7, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #973; RMG #4552\nTemplate reaction: Disproportionation\nFrom training reaction 9 used for C_rad/H/NonDeC;Cmethyl_Csrad\nExact match found for rate rule [C_rad/H/NonDeC;Cmethyl_Csrad]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 3.0\nfamily: Disproportionation'},
#  {'equation': 'S(227) (+M) <=> CH2OOH(37) + C3H6(12) (+M)',
#   'type': 'Chebyshev',
#   'temperature-range': [300.0, 2000.0],
#   'pressure-range': ['0.01 atm', '98.692 atm'],
#   'data': [[-5.303, -1.112, -0.202, 0.02532],
#    [13.2, 1.296, -0.2055, -0.01051],
#    [-0.1213, 0.572, 0.009123, -0.04111],
#    [-0.2786, 0.1577, 0.05508, -0.01826],
#    [-0.1264, 0.04507, 0.01912, 0.002236],
#    [-0.03606, 0.03875, -0.003466, 0.002889]],
#   'note': 'Reaction index: Chemkin #974; RMG #4579\nPDep reaction: PDepNetwork #65\nFlux pairs: S(227), CH2OOH(37); S(227), C3H6(12);'},
#  {'equation': 'O2(2) + C7H15(684) <=> S(918)',
#   'rate-constant': {'A': 121694800000000.0, 'b': -0.429, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #975; RMG #4610\nTemplate reaction: R_Recombination\nFlux pairs: C7H15(684), S(918); O2(2), S(918);\nBM rule fitted to 2 training reactions at node Root_N-1R->H_N-1CNOS->N_1COS->O_Ext-1O-R_Ext-2R-R_Ext-4R!H-R_Ext-2R-R_N-2R-inRing\n    Total Standard Deviation in ln(k): 11.5401827615\nExact match found for rate rule [Root_N-1R->H_N-1CNOS->N_1COS->O_Ext-1O-R_Ext-2R-R_Ext-4R!H-R_Ext-2R-R_N-2R-inRing]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: R_Recombination'},
#  {'equation': 'S(918) <=> S(927)',
#   'rate-constant': {'A': 135200000000.0, 'b': 0.21, 'Ea': 18.5},
#   'note': 'Reaction index: Chemkin #976; RMG #4624\nTemplate reaction: intra_H_migration\nFlux pairs: S(918), S(927);\nFrom training reaction 261 used for R5H_SSSS_OCC_C;O_rad_out;Cs_H_out_H/NonDeC\nExact match found for rate rule [R5H_SSSS_OCC_C;O_rad_out;Cs_H_out_H/NonDeC]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: intra_H_migration'},
#  {'equation': 'O2(2) + S(927) <=> S(947)',
#   'rate-constant': {'A': 14081700000000.0, 'b': -0.087, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #977; RMG #4676\nTemplate reaction: R_Recombination\nFlux pairs: S(927), S(947); O2(2), S(947);\nBM rule fitted to 2 training reactions at node Root_N-1R->H_N-1CNOS->N_1COS->O_Ext-1O-R_Ext-2R-R_Ext-4R!H-R_Ext-2R-R_Ext-5R!H-R_Ext-5R!H-R\n    Total Standard Deviation in ln(k): 11.5401827615\nExact match found for rate rule [Root_N-1R->H_N-1CNOS->N_1COS->O_Ext-1O-R_Ext-2R-R_Ext-4R!H-R_Ext-2R-R_Ext-5R!H-R_Ext-5R!H-R]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: R_Recombination'},
#  {'equation': 'H(14) + C7H15(687) <=> C7H16(1)',
#   'rate-constant': {'A': 91749900000000.0, 'b': 0.115, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #978; RMG #3435\nTemplate reaction: R_Recombination\nFlux pairs: C7H15(687), C7H16(1); H(14), C7H16(1);\nBM rule fitted to 2 training reactions at node Root_1R->H_N-2R->S_N-2CHNO->H_N-2CNO-inRing_Ext-2CNO-R_N-\nSp-3R!H=2CCNNOO_N-2CNO->O_3R!H->C_Sp-3C-2CN_Ext-3C-R_N-Sp-4R!H=3C_Sp-4R!H-3C\n    Total Standard Deviation in ln(k): 11.5401827615\nExact match found for rate rule [Root_1R->H_N-2R->S_N-2CHNO->H_N-2CNO-inRing_Ext-2CNO-R_N-Sp-3R!H=2CCNNOO_N-2CNO->O_3R!H->C_Sp-3C-2CN_Ext-3C-R_N-\nSp-4R!H=3C_Sp-4R!H-3C]\nEuclidian distance = 0\nfamily: R_Recombination'},
#  {'equation': 'HO2(17) + C7H15(687) <=> O2(2) + C7H16(1)',
#   'rate-constant': {'A': 3.062323, 'b': 3.295, 'Ea0': 9.354, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #979; RMG #3439\nTemplate reaction: H_Abstraction\nFlux pairs: HO2(17), O2(2); C7H15(687), C7H16(1);\nEstimated using template [X_H;C_rad/H2/Cs] for rate rule [Orad_O_H;C_rad/H2/Cs]\nEuclidian distance = 2.0\nfamily: H_Abstraction'},
#  {'equation': 'O(5) + C7H16(1) <=> OH(15) + C7H15(687)',
#   'rate-constant': {'A': 1940.0, 'b': 3.23, 'Ea0': 4.66, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #980; RMG #3443\nTemplate reaction: H_Abstraction\nFlux pairs: O(5), OH(15); C7H16(1), C7H15(687);\nEstimated using template [C/H3/Cs\\OneNonDe;O_atom_triplet] for rate rule [C/H3/Cs\\H2\\Cs;O_atom_triplet]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 6.0\nfamily: H_Abstraction'},
#  {'equation': 'H(14) + C7H16(1) <=> H2(13) + C7H15(687)',
#   'rate-constant': {'A': 16638.24, 'b': 2.718, 'Ea0': 6.496, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #981; RMG #3500\nTemplate reaction: H_Abstraction\nFlux pairs: H(14), H2(13); C7H16(1), C7H15(687);\nEstimated using average of templates [C/H3/Cs\\OneNonDe;H_rad] + [C/H3/Cs\\H2\\Cs;Y_rad] for rate rule [C/H3/Cs\\H2\\Cs;H_rad]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 6.0\nfamily: H_Abstraction'},
#  {'equation': 'OH(15) + C7H16(1) <=> H2O(8) + C7H15(687)',
#   'rate-constant': {'A': 18800.0, 'b': 2.67, 'Ea0': -1.004, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #982; RMG #3504\nTemplate reaction: H_Abstraction\nFlux pairs: OH(15), H2O(8); C7H16(1), C7H15(687);\nEstimated using template [C/H3/Cs\\OneNonDe;O_pri_rad] for rate rule [C/H3/Cs\\H2\\Cs;O_pri_rad]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 6.0\nfamily: H_Abstraction'},
#  {'equation': 'H2O2(18) + C7H15(687) <=> HO2(17) + C7H16(1)',
#   'rate-constant': {'A': 1.773899, 'b': 3.328, 'Ea0': 1.143, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #983; RMG #3509\nTemplate reaction: H_Abstraction\nFlux pairs: H2O2(18), HO2(17); C7H15(687), C7H16(1);\nEstimated using an average for rate rule [H2O2;C_rad/H2/Cs]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3(19) + C7H16(1) <=> CH4(10) + C7H15(687)',
#   'rate-constant': {'A': 4.0, 'b': 3.57, 'Ea0': 7.717, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #984; RMG #3514\nTemplate reaction: H_Abstraction\nFlux pairs: CH3(19), CH4(10); C7H16(1), C7H15(687);\nEstimated using template [C/H3/Cs\\OneNonDe;C_methyl] for rate rule [C/H3/Cs\\H2\\Cs;C_methyl]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 6.0\nfamily: H_Abstraction'},
#  {'equation': 'CH3OOH(36) + C7H15(687) <=> CH3OO(33) + C7H16(1)',
#   'rate-constant': {'A': 0.0006391396, 'b': 4.352, 'Ea0': -1.737, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #985; RMG #3519\nTemplate reaction: H_Abstraction\nFlux pairs: CH3OOH(36), CH3OO(33); C7H15(687), C7H16(1);\nEstimated using an average for rate rule [O/H/NonDeO;C_rad/H2/Cs]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -7.3 to -7.3 kJ/mol.'},
#  {'equation': 'C2H5(34) + C7H16(1) <=> C2H6(38) + C7H15(687)',
#   'rate-constant': {'A': 0.00552, 'b': 4.34, 'Ea0': 9.2, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #986; RMG #3525\nTemplate reaction: H_Abstraction\nFlux pairs: C2H5(34), C2H6(38); C7H16(1), C7H15(687);\nEstimated using template [C/H3/Cs;C_rad/H2/Cs\\H3] for rate rule [C/H3/Cs\\H2\\Cs;C_rad/H2/Cs\\H3]\nEuclidian distance = 2.0\nMultiplied by reaction path degeneracy 6.0\nfamily: H_Abstraction'},
#  {'equation': 'C2H5O(56) + C7H15(687) <=> CH3CHO(39) + C7H16(1)',
#   'rate-constant': {'A': 2410000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #987; RMG #3530\nTemplate reaction: Disproportionation\nFrom training reaction 58 used for C_rad/H2/Cs;O_Csrad\nExact match found for rate rule [C_rad/H2/Cs;O_Csrad]\nEuclidian distance = 0\nfamily: Disproportionation'},
#  {'equation': 'C2H5O(40) + C7H15(687) <=> CH3CHO(39) + C7H16(1)',
#   'rate-constant': {'A': 2900000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #988; RMG #3534\nTemplate reaction: Disproportionation\nEstimated using template [C_rad/H2/Cs;C/H2/Nd_Rrad] for rate rule [C_rad/H2/Cs;C/H2/Nd_Orad]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 2.0\nfamily: Disproportionation'},
#  {'equation': 'C2H6O2(62) + C7H15(687) <=> C2H5O2(41) + C7H16(1)',
#   'rate-constant': {'A': 2.51e-11, 'b': 6.77, 'Ea0': -8.6, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #989; RMG #3540\nTemplate reaction: H_Abstraction\nFlux pairs: C2H6O2(62), C2H5O2(41); C7H15(687), C7H16(1);\nEstimated using an average for rate rule [ROOH_pri;C_rad/H2/Cs]\nEuclidian distance = 0\nfamily: H_Abstraction\nEa raised from -36.0 to -36.0 kJ/mol.'},
#  {'equation': 'CH2OH(30) + C7H15(687) <=> CH2O(9) + C7H16(1)',
#   'rate-constant': {'A': 2410000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #990; RMG #3551\nTemplate reaction: Disproportionation\nFrom training reaction 58 used for C_rad/H2/Cs;O_Csrad\nExact match found for rate rule [C_rad/H2/Cs;O_Csrad]\nEuclidian distance = 0\nfamily: Disproportionation'},
#  {'equation': 'CH3O(31) + C7H15(687) <=> CH2O(9) + C7H16(1)',
#   'rate-constant': {'A': 69000000000000.0, 'b': -0.35, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #991; RMG #3552\nTemplate reaction: Disproportionation\nEstimated using template [C_rad/H2/Cs;Cmethyl_Rrad] for rate rule [C_rad/H2/Cs;Cmethyl_Orad]\nEuclidian distance = 1.0\nMultiplied by reaction path degeneracy 3.0\nfamily: Disproportionation'},
#  {'equation': 'C2H5(34) + C7H15(687) <=> C2H4(11) + C7H16(1)',
#   'rate-constant': {'A': 69000000000000.0, 'b': -0.35, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #992; RMG #3556\nTemplate reaction: Disproportionation\nFrom training reaction 6 used for C_rad/H2/Cs;Cmethyl_Csrad\nExact match found for rate rule [C_rad/H2/Cs;Cmethyl_Csrad]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 3.0\nfamily: Disproportionation'},
#  {'equation': 'NC3H7(100) + C7H15(687) <=> C3H6(12) + C7H16(1)',
#   'rate-constant': {'A': 2900000000000.0, 'b': 0.0, 'Ea': 0.0},
#   'note': 'Reaction index: Chemkin #993; RMG #3563\nTemplate reaction: Disproportionation\nFrom training reaction 21 used for C_rad/H2/Cs;C/H2/Nd_Csrad\nExact match found for rate rule [C_rad/H2/Cs;C/H2/Nd_Csrad]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: Disproportionation'},
#  {'equation': 'C7H15(687) <=> C7H15(686)',
#   'duplicate': True,
#   'rate-constant': {'A': 25800.0, 'b': 1.67, 'Ea': 10.2},
#   'note': 'Reaction index: Chemkin #994; RMG #4249\nTemplate reaction: intra_H_migration\nFlux pairs: C7H15(687), C7H15(686);\nMatched reaction 114 CCCCCC[CH2]-1 <=> C[CH]CCCCC in intra_H_migration/training\nThis reaction matched rate rule [R2H_S;C_rad_out_H/NonDeC;Cs_H_out_2H]\nfamily: intra_H_migration'},
#  {'equation': 'C7H15(687) <=> C7H15(686)',
#   'duplicate': True,
#   'rate-constant': {'A': 25800.0, 'b': 1.67, 'Ea': 10.2},
#   'note': 'Reaction index: Chemkin #995; RMG #4252\nTemplate reaction: intra_H_migration\nFlux pairs: C7H15(687), C7H15(686);\nMatched reaction 114 CCCCCC[CH2]-1 <=> C[CH]CCCCC in intra_H_migration/training\nThis reaction matched rate rule [R6H_SSSSS;C_rad_out_H/NonDeC;Cs_H_out_2H]\nfamily: intra_H_migration'},
#  {'equation': 'C2H5O(40) + C7H16(1) <=> C2H6O(55) + C7H15(687)',
#   'rate-constant': {'A': 24000.0, 'b': 2.55, 'Ea0': 15.75, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #996; RMG #4257\nTemplate reaction: H_Abstraction\nFlux pairs: C2H5O(40), C2H6O(55); C7H16(1), C7H15(687);\nEstimated using template [C/H3/Cs\\OneNonDe;O_sec_rad] for rate rule [C/H3/Cs\\H2\\Cs;O_rad/NonDeC]\nEuclidian distance = 1.4142135623730951\nMultiplied by reaction path degeneracy 6.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(687) + C7H16(1) <=> C7H15(686) + C7H16(1)',
#   'rate-constant': {'A': 0.004327734, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #997; RMG #4268\nTemplate reaction: H_Abstraction\nFlux pairs: C7H16(1), C7H15(686); C7H15(687), C7H16(1);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H2/Cs]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  {'equation': 'C7H15(687) <=> C7H15(683)',
#   'duplicate': True,
#   'rate-constant': {'A': 1064000.0, 'b': 1.93, 'Ea': 33.8},
#   'note': 'Reaction index: Chemkin #998; RMG #4449\nTemplate reaction: intra_H_migration\nFlux pairs: C7H15(687), C7H15(683);\nFrom training reaction 108 used for R3H_SS_Cs;C_rad_out_2H;Cs_H_out_H/(NonDeC/Cs)\nExact match found for rate rule [R3H_SS_Cs;C_rad_out_2H;Cs_H_out_H/(NonDeC/Cs)]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: intra_H_migration'},
#  {'equation': 'C7H15(687) <=> C7H15(683)',
#   'duplicate': True,
#   'rate-constant': {'A': 1064000.0, 'b': 1.93, 'Ea': 33.8},
#   'note': 'Reaction index: Chemkin #999; RMG #4451\nTemplate reaction: intra_H_migration\nFlux pairs: C7H15(687), C7H15(683);\nFrom training reaction 108 used for R3H_SS_Cs;C_rad_out_2H;Cs_H_out_H/(NonDeC/Cs)\nExact match found for rate rule [R3H_SS_Cs;C_rad_out_2H;Cs_H_out_H/(NonDeC/Cs)]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 2.0\nfamily: intra_H_migration'},
#  {'equation': 'C7H15(687) + C7H16(1) <=> C7H15(683) + C7H16(1)',
#   'rate-constant': {'A': 0.004327734, 'b': 4.29, 'Ea0': 7.536, 'w': 239.0},
#   'note': 'Reaction index: Chemkin #1000; RMG #4453\nTemplate reaction: H_Abstraction\nFlux pairs: C7H16(1), C7H15(683); C7H15(687), C7H16(1);\nEstimated using an average for rate rule [C/H2/NonDeC;C_rad/H2/Cs]\nEuclidian distance = 0\nMultiplied by reaction path degeneracy 4.0\nfamily: H_Abstraction'},
#  ...]
