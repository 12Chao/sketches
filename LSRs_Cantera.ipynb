# %% [markdown]
# # Scaling in Cantera
# This notebook is where we figure out how to do linear scaling relationships, in Cantera

# %%
import sys
sys.executable = '/home/chao/anaconda3/envs/rmg_env/bin/python'
python_path = ['','/home/chao/cantera/build/python', '/home/chao/RMG-Py', '/home/chao', '/home/chao/anaconda3/envs/rmg_env/lib/python37.zip', '/home/chao/anaconda3/envs/rmg_env/lib/python3.7', '/home/chao/anaconda3/envs/rmg_env/lib/python3.7/lib-dynload', '/home/chao/anaconda3/envs/rmg_env/lib/python3.7/site-packages', '/home/chao/anaconda3/envs/rmg_env/lib/python3.7/site-packages/chemprop-0.0.1-py3.7.egg', '/home/chao/anaconda3/envs/rmg_env/lib/python3.7/site-packages/descriptastorus-2.0.0.32-py3.7.egg']
sys.path.clear()
for path in python_path:
    sys.path.append(path)

# %%
import numpy as np
import scipy, scipy.optimize

# %matplotlib inline
from matplotlib import pyplot as plt

import cantera as ct

import rmgpy
import rmgpy.data.base
import rmgpy.molecule
import rmgpy.quantity

# %%
def find_species_phase_index(species_name):
    """
    Return the phase object (gas or surface) and the index
    of the named species.
    """
    try:
        i = gas.species_index(species_name)
        return gas, i
    except ValueError:
        i = surf.species_index(species_name)
        return surf, i

def change_species_enthalpy(species_name, dH):
    """
    Find the species by name and change it's enthlapy by dH (in J/kmol)
    """
    phase, index = find_species_phase_index(species_name)

    species = phase.species(index)
    print(f"Initial H(298) = {species.thermo.h(298)/1e6:.1f} kJ/mol")
    dx = dH / ct.gas_constant  # 'dx' is in fact (delta H / R). Note that R in cantera is 8314.462 J/kmol
    assert isinstance(species.thermo, ct.NasaPoly2)
    # print(species.thermo.coeffs)
    perturbed_coeffs = species.thermo.coeffs.copy()
    perturbed_coeffs[6] += dx
    perturbed_coeffs[13] += dx
    
    species.thermo = ct.NasaPoly2(species.thermo.min_temp, species.thermo.max_temp, 
                            species.thermo.reference_pressure, perturbed_coeffs)
    #print(species.thermo.coeffs)
    phase.modify_species(index, species)
    print(f"Modified H(298) = {species.thermo.h(298)/1e6:.1f} kJ/mol")

# change_species_enthalpy('NH4NO3', 1e6) # 1 kJ/mol = 1e6 J/kmol
# change_species_enthalpy('NH4NO3', -1e6) # put it back for now

# %%
def correct_binding_energy(species, delta_atomic_adsoprtion_energies={}):
    """
    Changes the thermo of the provided species, by applying a linear scaling relation
    to correct the adsorption energy.

    :param species: The species to modify (an RMG Species object)
    :param delta_atomic_adsoprtion_energies: a dictionary of changes in atomic adsorption energies to apply.
        mapping for each element an RMG Quantity objects with .value_si giving a value in J/mol.
    :return: None
    """
    molecule = species.molecule[0]
    # only want/need to do one resonance structure
    surface_sites = []
    for atom in molecule.atoms:
        if atom.is_surface_site():
            surface_sites.append(atom)
    normalized_bonds = {'C': 0., 'O': 0., 'N': 0., 'H': 0.}
    max_bond_order = {'C': 4., 'O': 2., 'N': 3., 'H': 1.}
    for site in surface_sites:
        numbonds = len(site.bonds)
        if numbonds == 0:
            # vanDerWaals
            pass
        else:
            assert len(site.bonds) == 1, "Each surface site can only be bonded to 1 atom"
            bonded_atom = list(site.bonds.keys())[0]
            bond = site.bonds[bonded_atom]
            if bond.is_single():
                bond_order = 1.
            elif bond.is_double():
                bond_order = 2.
            elif bond.is_triple():
                bond_order = 3.
            elif bond.is_quadruple():
                bond_order = 4.
            else:
                raise NotImplementedError("Unsupported bond order {0} for binding energy "
                                          "correction.".format(bond.order))

            normalized_bonds[bonded_atom.symbol] += bond_order / max_bond_order[bonded_atom.symbol]


    # now edit the adsorptionThermo using LSR
    change_in_binding_energy = 0.0
    for element in delta_atomic_adsoprtion_energies.keys():
        change_in_binding_energy += delta_atomic_adsoprtion_energies[element].value_si * normalized_bonds[element]
    if change_in_binding_energy != 0.0:
        print(f"Applying LSR correction to {species.label}:")
        change_species_enthalpy(species.label, change_in_binding_energy*1000)

# %%
# Create Gas Solution and Surface Interface from cti file
cti_file = "./chem_annotated_Pt_large.cti" # path to cti file
gas = ct.Solution(cti_file)
surf = ct.Interface(cti_file,'surface1', [gas])
species_dict = rmgpy.data.base.Database().get_species('species_dictionary_Pt_large.txt',resonance=False)
#species_dict = rmgpy.data.base.Database().get_species('../RMG-model/chemkin/species_dictionary.txt',resonance=False)

# %%
delta_atomic_adsoprtion_energies = {
    "C" : rmgpy.quantity.Energy(-2,'kcal/mol'),
    "O" : rmgpy.quantity.Energy(3,'kcal/mol'),
    "N" : rmgpy.quantity.Energy(-5,'kcal/mol'),
}

# %%
for species in surf.species():
    rmg_spcs = species_dict[species.name]
    correct_binding_energy(rmg_spcs, delta_atomic_adsoprtion_energies)
# Out:
# Applying LSR correction to HO_Pd(30):
# Initial H(298) = -155.9 kJ/mol
# Modified H(298) = -149.6 kJ/mol
# Applying LSR correction to H2NOX(31):
# Initial H(298) = -145.0 kJ/mol
# Modified H(298) = -138.7 kJ/mol
# Applying LSR correction to N_Pt(35):
# Initial H(298) = 40.1 kJ/mol
# Modified H(298) = 19.2 kJ/mol
# Applying LSR correction to O_Pt(36):
# Initial H(298) = -140.5 kJ/mol
# Modified H(298) = -127.9 kJ/mol
# Applying LSR correction to NO_Pt(37):
# Initial H(298) = -107.6 kJ/mol
# Modified H(298) = -114.6 kJ/mol
# Applying LSR correction to CH3X(39):
# Initial H(298) = -45.8 kJ/mol
# Modified H(298) = -47.9 kJ/mol
# Applying LSR correction to OCX(41):
# Initial H(298) = -281.4 kJ/mol
# Modified H(298) = -285.6 kJ/mol
# Applying LSR correction to CX(42):
# Initial H(298) = 53.6 kJ/mol
# Modified H(298) = 45.3 kJ/mol
# Applying LSR correction to CH2X(43):
# Initial H(298) = 0.7 kJ/mol
# Modified H(298) = -3.5 kJ/mol
# Applying LSR correction to CHX(44):
# Initial H(298) = -25.4 kJ/mol
# Modified H(298) = -31.7 kJ/mol
# Applying LSR correction to H2NX(244):
# Initial H(298) = -37.4 kJ/mol
# Modified H(298) = -44.3 kJ/mol
# Applying LSR correction to H2NOX(245):
# Initial H(298) = -90.6 kJ/mol
# Modified H(298) = -97.6 kJ/mol
# Applying LSR correction to NO2JX(251):
# Initial H(298) = -167.4 kJ/mol
# Modified H(298) = -174.3 kJ/mol
# Applying LSR correction to HNX(259):
# Initial H(298) = -10.5 kJ/mol
# Modified H(298) = -24.5 kJ/mol
# Applying LSR correction to NO2JX(353):
# Initial H(298) = -111.0 kJ/mol
# Modified H(298) = -104.7 kJ/mol
# Applying LSR correction to SX(408):
# Initial H(298) = -146.1 kJ/mol
# Modified H(298) = -139.9 kJ/mol
# Applying LSR correction to CH3OX(429):
# Initial H(298) = -285.4 kJ/mol
# Modified H(298) = -287.5 kJ/mol
# Applying LSR correction to CHOX(436):
# Initial H(298) = -224.4 kJ/mol
# Modified H(298) = -226.5 kJ/mol
# Applying LSR correction to H2NOX(764):
# Initial H(298) = -133.4 kJ/mol
# Modified H(298) = -140.4 kJ/mol
# Applying LSR correction to HNOX(1864):
# Initial H(298) = -18.5 kJ/mol
# Modified H(298) = -32.5 kJ/mol
# Applying LSR correction to SX(4090):
# Initial H(298) = -278.7 kJ/mol
# Modified H(298) = -280.8 kJ/mol
# Applying LSR correction to CHOX(4093):
# Initial H(298) = -249.5 kJ/mol
# Modified H(298) = -255.8 kJ/mol
# Applying LSR correction to SX(7973):
# Initial H(298) = -211.2 kJ/mol
# Modified H(298) = -215.4 kJ/mol

# %%
species_dict
# Out:
# OrderedDict([('SX(26)',
#               Species(label="SX(26)", molecule=[Molecule(smiles="[O-][N+](=O)[O-].[Pt].[NH4+]")], molecular_weight=(80.0434,'amu'))),
#              ('N2O_X(27)',
#               Species(label="N2O_X(27)", molecule=[Molecule(smiles="[N-]=[N+]=O.[Pt]")], molecular_weight=(44.0129,'amu'))),
#              ('H2O_X(28)',
#               Species(label="H2O_X(28)", molecule=[Molecule(smiles="O.[Pt]")], molecular_weight=(18.0153,'amu'))),
#              ('HAN_X(29)',
#               Species(label="HAN_X(29)", molecule=[Molecule(smiles="[O-][N+](=O)[O-].O[NH3+].[Pt]")], molecular_weight=(96.0428,'amu'))),
#              ('HO_Pd(30)',
#               Species(label="HO_Pd(30)", molecule=[Molecule(smiles="O[Pt]")], molecular_weight=(17.0073,'amu'))),
#              ('H2NOX(31)',
#               Species(label="H2NOX(31)", molecule=[Molecule(smiles="NO[Pt]")], molecular_weight=(32.022,'amu'))),
#              ('HONO(32)',
#               Species(label="HONO(32)", molecule=[Molecule(smiles="ON=O")], molecular_weight=(47.0135,'amu'))),
#              ('H3NOX(33)',
#               Species(label="H3NOX(33)", molecule=[Molecule(smiles="NO.[Pt]")], molecular_weight=(33.03,'amu'))),
#              ('HNO3_X(34)',
#               Species(label="HNO3_X(34)", molecule=[Molecule(smiles="[O-][N+](=O)O.[Pt]")], molecular_weight=(63.0129,'amu'))),
#              ('N_Pt(35)',
#               Species(label="N_Pt(35)", molecule=[Molecule(smiles="N#[Pt]")], molecular_weight=(14.0067,'amu'))),
#              ('O_Pt(36)',
#               Species(label="O_Pt(36)", molecule=[Molecule(smiles="O=[Pt]")], molecular_weight=(15.9994,'amu'))),
#              ('NO_Pt(37)',
#               Species(label="NO_Pt(37)", molecule=[Molecule(smiles="[Pt]N=O")], molecular_weight=(30.0061,'amu'))),
#              ('HAN',
#               Species(label="HAN", molecule=[Molecule(smiles="[O-][N+](=O)[O-].O[NH3+]")], molecular_weight=(96.0428,'amu'))),
#              ('NH4NO3',
#               Species(label="NH4NO3", molecule=[Molecule(smiles="[O-][N+](=O)[O-].[NH4+]")], molecular_weight=(80.0434,'amu'))),
#              ('Ne',
#               Species(label="Ne", molecule=[Molecule(smiles="[Ne]")], molecular_weight=(20.1797,'amu'))),
#              ('X(1)',
#               Species(label="X(1)", molecule=[Molecule(smiles="[Pt]")], molecular_weight=(0,'amu'))),
#              ('NH3(2)',
#               Species(label="NH3(2)", molecule=[Molecule(smiles="N")], molecular_weight=(17.0306,'amu'))),
#              ('NH2OH(3)',
#               Species(label="NH2OH(3)", molecule=[Molecule(smiles="NO")], molecular_weight=(33.03,'amu'))),
#              ('HNO3(4)',
#               Species(label="HNO3(4)", molecule=[Molecule(smiles="[O-][N+](=O)O")], molecular_weight=(63.0129,'amu'))),
#              ('CH3OH(5)',
#               Species(label="CH3OH(5)", molecule=[Molecule(smiles="CO")], molecular_weight=(32.0419,'amu'))),
#              ('H2O(6)',
#               Species(label="H2O(6)", molecule=[Molecule(smiles="O")], molecular_weight=(18.0153,'amu'))),
#              ('N2(7)',
#               Species(label="N2(7)", molecule=[Molecule(smiles="N#N")], molecular_weight=(28.0135,'amu'))),
#              ('O2(8)',
#               Species(label="O2(8)", molecule=[Molecule(smiles="[O][O]")], molecular_weight=(31.9988,'amu'))),
#              ('NO2(9)',
#               Species(label="NO2(9)", molecule=[Molecule(smiles="[O-][N+]=O")], molecular_weight=(46.0055,'amu'))),
#              ('NO(10)',
#               Species(label="NO(10)", molecule=[Molecule(smiles="[N]=O")], molecular_weight=(30.0061,'amu'))),
#              ('N2O(11)',
#               Species(label="N2O(11)", molecule=[Molecule(smiles="[N-]=[N+]=O")], molecular_weight=(44.0129,'amu'))),
#              ('CO2(12)',
#               Species(label="CO2(12)", molecule=[Molecule(smiles="O=C=O")], molecular_weight=(44.0095,'amu'))),
#              ('H2(13)',
#               Species(label="H2(13)", molecule=[Molecule(smiles="[H][H]")], molecular_weight=(2.01588,'amu'))),
#              ('CO(14)',
#               Species(label="CO(14)", molecule=[Molecule(smiles="[C-]#[O+]")], molecular_weight=(28.0101,'amu'))),
#              ('CH4(15)',
#               Species(label="CH4(15)", molecule=[Molecule(smiles="C")], molecular_weight=(16.0425,'amu'))),
#              ('C2H6(16)',
#               Species(label="C2H6(16)", molecule=[Molecule(smiles="CC")], molecular_weight=(30.069,'amu'))),
#              ('CH2O(17)',
#               Species(label="CH2O(17)", molecule=[Molecule(smiles="C=O")], molecular_weight=(30.026,'amu'))),
#              ('CH3(18)',
#               Species(label="CH3(18)", molecule=[Molecule(smiles="[CH3]")], molecular_weight=(15.0345,'amu'))),
#              ('C3H8(19)',
#               Species(label="C3H8(19)", molecule=[Molecule(smiles="CCC")], molecular_weight=(44.0956,'amu'))),
#              ('H(20)',
#               Species(label="H(20)", molecule=[Molecule(smiles="[H]")], molecular_weight=(1.00794,'amu'))),
#              ('C2H5(21)',
#               Species(label="C2H5(21)", molecule=[Molecule(smiles="C[CH2]")], molecular_weight=(29.0611,'amu'))),
#              ('HCO(22)',
#               Species(label="HCO(22)", molecule=[Molecule(smiles="[CH]=O")], molecular_weight=(29.018,'amu'))),
#              ('CH3CHO(23)',
#               Species(label="CH3CHO(23)", molecule=[Molecule(smiles="CC=O")], molecular_weight=(44.0526,'amu'))),
#              ('OH(24)',
#               Species(label="OH(24)", molecule=[Molecule(smiles="[OH]")], molecular_weight=(17.0073,'amu'))),
#              ('C2H4(25)',
#               Species(label="C2H4(25)", molecule=[Molecule(smiles="C=C")], molecular_weight=(28.0532,'amu'))),
#              ('HX(38)',
#               Species(label="HX(38)", molecule=[Molecule(smiles="[Pt]")], molecular_weight=(1.00794,'amu'))),
#              ('H2NX(244)',
#               Species(label="H2NX(244)", molecule=[Molecule(smiles="N[Pt]")], molecular_weight=(16.0226,'amu'))),
#              ('CH4OX(430)',
#               Species(label="CH4OX(430)", molecule=[Molecule(smiles="CO.[Pt]")], molecular_weight=(32.0419,'amu'))),
#              ('NO2JX(353)',
#               Species(label="NO2JX(353)", molecule=[Molecule(smiles="[Pt]ON=O")], molecular_weight=(46.0055,'amu'))),
#              ('H2NO(97)',
#               Species(label="H2NO(97)", molecule=[Molecule(smiles="N[O]")], molecular_weight=(32.022,'amu'))),
#              ('N2O4(528)',
#               Species(label="N2O4(528)", molecule=[Molecule(smiles="O=NO[N+](=O)[O-]")], molecular_weight=(92.0111,'amu'))),
#              ('HNO2(102)',
#               Species(label="HNO2(102)", molecule=[Molecule(smiles="[O-][NH+]=O")], molecular_weight=(47.0135,'amu'))),
#              ('HNO(96)',
#               Species(label="HNO(96)", molecule=[Molecule(smiles="N=O")], molecular_weight=(31.0141,'amu'))),
#              ('CH2OH(54)',
#               Species(label="CH2OH(54)", molecule=[Molecule(smiles="[CH2]O")], molecular_weight=(31.0339,'amu'))),
#              ('S(954)',
#               Species(label="S(954)", molecule=[Molecule(smiles="[O-][N+](=O)CO")], molecular_weight=(77.0395,'amu'))),
#              ('S(972)',
#               Species(label="S(972)", molecule=[Molecule(smiles="[O-][NH2+]CO")], molecular_weight=(63.0559,'amu'))),
#              ('N2O2(425)',
#               Species(label="N2O2(425)", molecule=[Molecule(smiles="O=NN=O")], molecular_weight=(60.0123,'amu'))),
#              ('HNX(259)',
#               Species(label="HNX(259)", molecule=[Molecule(smiles="N=[Pt]")], molecular_weight=(15.0147,'amu'))),
#              ('ONONO(537)',
#               Species(label="ONONO(537)", molecule=[Molecule(smiles="O=NON=O")], molecular_weight=(76.0117,'amu'))),
#              ('CH3O(55)',
#               Species(label="CH3O(55)", molecule=[Molecule(smiles="C[O]")], molecular_weight=(31.0339,'amu'))),
#              ('H2NOX(245)',
#               Species(label="H2NOX(245)", molecule=[Molecule(smiles="ON[Pt]")], molecular_weight=(32.022,'amu'))),
#              ('NONDO(346)',
#               Species(label="NONDO(346)", molecule=[Molecule(smiles="NON=O")], molecular_weight=(62.0282,'amu'))),
#              ('N2O4(525)',
#               Species(label="N2O4(525)", molecule=[Molecule(smiles="[O-][N+](=O)[N+](=O)[O-]")], molecular_weight=(92.0111,'amu'))),
#              ('S(802)',
#               Species(label="S(802)", molecule=[Molecule(smiles="[O-][NH2+]C=O")], molecular_weight=(61.0401,'amu'))),
#              ('S(810)',
#               Species(label="S(810)", molecule=[Molecule(smiles="[O-][NH2+]ON")], molecular_weight=(64.044,'amu'))),
#              ('HNO(758)',
#               Species(label="HNO(758)", molecule=[Molecule(smiles="[NH][O]")], molecular_weight=(31.0141,'amu'))),
#              ('H3NO(761)',
#               Species(label="H3NO(761)", molecule=[Molecule(smiles="[O-][NH3+]")], molecular_weight=(33.03,'amu'))),
#              ('OCNDO(958)',
#               Species(label="OCNDO(958)", molecule=[Molecule(smiles="OCN=O")], molecular_weight=(61.0401,'amu'))),
#              ('S(780)',
#               Species(label="S(780)", molecule=[Molecule(smiles="[O-][NH2+]N=O")], molecular_weight=(62.0282,'amu'))),
#              ('H3NX(427)',
#               Species(label="H3NX(427)", molecule=[Molecule(smiles="[Pt].N")], molecular_weight=(17.0306,'amu'))),
#              ('SX(408)',
#               Species(label="SX(408)", molecule=[Molecule(smiles="ONO[Pt]")], molecular_weight=(48.0214,'amu'))),
#              ('HNOH(101)',
#               Species(label="HNOH(101)", molecule=[Molecule(smiles="[NH]O")], molecular_weight=(32.022,'amu'))),
#              ('CHNO2(589)',
#               Species(label="CHNO2(589)", molecule=[Molecule(smiles="O=NC=O")], molecular_weight=(59.0242,'amu'))),
#              ('H2NOX(764)',
#               Species(label="H2NOX(764)", molecule=[Molecule(smiles="[O-][NH2+][Pt]")], molecular_weight=(32.022,'amu'))),
#              ('HONOX(308)',
#               Species(label="HONOX(308)", molecule=[Molecule(smiles="ON=O.[Pt]")], molecular_weight=(47.0135,'amu'))),
#              ('ONCO(1643)',
#               Species(label="ONCO(1643)", molecule=[Molecule(smiles="ONCO")], molecular_weight=(63.0559,'amu'))),
#              ('S(1419)',
#               Species(label="S(1419)", molecule=[Molecule(smiles="ON=CO")], molecular_weight=(61.0401,'amu'))),
#              ('S(1405)',
#               Species(label="S(1405)", molecule=[Molecule(smiles="[O-][NH+]=[C][O]")], molecular_weight=(59.0242,'amu'))),
#              ('S(2051)',
#               Species(label="S(2051)", molecule=[Molecule(smiles="N1OC1=O")], molecular_weight=(59.0242,'amu'))),
#              ('S(2268)',
#               Species(label="S(2268)", molecule=[Molecule(smiles="[O]C(=N)[O]")], molecular_weight=(59.0242,'amu'))),
#              ('ONCDO(461)',
#               Species(label="ONCDO(461)", molecule=[Molecule(smiles="ONC=O")], molecular_weight=(61.0401,'amu'))),
#              ('N2X(431)',
#               Species(label="N2X(431)", molecule=[Molecule(smiles="N#N.[Pt]")], molecular_weight=(28.0135,'amu'))),
#              ('NO2JX(251)',
#               Species(label="NO2JX(251)", molecule=[Molecule(smiles="[O-][N+](=O)[Pt]")], molecular_weight=(46.0055,'amu'))),
#              ('S(774)',
#               Species(label="S(774)", molecule=[Molecule(smiles="[O-][NH2+][N+](=O)[O-]")], molecular_weight=(78.0276,'amu'))),
#              ('NO2NO(534)',
#               Species(label="NO2NO(534)", molecule=[Molecule(smiles="O=N[N+](=O)[O-]")], molecular_weight=(76.0117,'amu'))),
#              ('SX(990)',
#               Species(label="SX(990)", molecule=[Molecule(smiles="[O-][N+](=O)CO.[Pt]")], molecular_weight=(77.0395,'amu'))),
#              ('S(2749)',
#               Species(label="S(2749)", molecule=[Molecule(smiles="[O-]C[NH+]=O")], molecular_weight=(61.0401,'amu'))),
#              ('S(938)',
#               Species(label="S(938)", molecule=[Molecule(smiles="[O-][NH2+]O[NH]")], molecular_weight=(63.0361,'amu'))),
#              ('S(811)',
#               Species(label="S(811)", molecule=[Molecule(smiles="[O-][NH2+][NH2+][O-]")], molecular_weight=(64.044,'amu'))),
#              ('H2NO3(356)',
#               Species(label="H2NO3(356)", molecule=[Molecule(smiles="ON(O)[O]")], molecular_weight=(64.0208,'amu'))),
#              ('NO3(103)',
#               Species(label="NO3(103)", molecule=[Molecule(smiles="[O-][N+](=O)[O]")], molecular_weight=(62.0049,'amu'))),
#              ('S(2555)',
#               Species(label="S(2555)", molecule=[Molecule(smiles="[O-][NH2+]OC(=N)[O]")], molecular_weight=(91.0462,'amu'))),
#              ('NOON(335)',
#               Species(label="NOON(335)", molecule=[Molecule(smiles="NOON")], molecular_weight=(64.044,'amu'))),
#              ('OCX(41)',
#               Species(label="OCX(41)", molecule=[Molecule(smiles="O=C=[Pt]")], molecular_weight=(28.0101,'amu'))),
#              ('HN2O2(915)',
#               Species(label="HN2O2(915)", molecule=[Molecule(smiles="[N-]([NH+]=O)[O]")], molecular_weight=(61.0202,'amu'))),
#              ('HN2O2(914)',
#               Species(label="HN2O2(914)", molecule=[Molecule(smiles="[NH]ON=O")], molecular_weight=(61.0202,'amu'))),
#              ('CH2OX(437)',
#               Species(label="CH2OX(437)", molecule=[Molecule(smiles="C=O.[Pt]")], molecular_weight=(30.026,'amu'))),
#              ('SX(1860)',
#               Species(label="SX(1860)", molecule=[Molecule(smiles="[O-][NH2+][N+](=O)[O-].[Pt]")], molecular_weight=(78.0276,'amu'))),
#              ('HN2O4(363)',
#               Species(label="HN2O4(363)", molecule=[Molecule(smiles="[O-][N+](=O)O[N]O")], molecular_weight=(93.019,'amu'))),
#              ('NH2(94)',
#               Species(label="NH2(94)", molecule=[Molecule(smiles="[NH2]")], molecular_weight=(16.0226,'amu'))),
#              ('NH2NO(691)',
#               Species(label="NH2NO(691)", molecule=[Molecule(smiles="NN=O")], molecular_weight=(46.0288,'amu'))),
#              ('S(1206)',
#               Species(label="S(1206)", molecule=[Molecule(smiles="ONN=O")], molecular_weight=(62.0282,'amu'))),
#              ('CNO2(2424)',
#               Species(label="CNO2(2424)", molecule=[Molecule(smiles="[O]C(=[N])[O]")], molecular_weight=(58.0162,'amu'))),
#              ('S(5736)',
#               Species(label="S(5736)", molecule=[Molecule(smiles="O=NN=C([O])[O]")], molecular_weight=(88.0224,'amu'))),
#              ('S(2477)',
#               Species(label="S(2477)", molecule=[Molecule(smiles="[O]C(=N)ON=O")], molecular_weight=(89.0303,'amu'))),
#              ('CHOX(436)',
#               Species(label="CHOX(436)", molecule=[Molecule(smiles="O=C[Pt]")], molecular_weight=(29.018,'amu'))),
#              ('S(779)',
#               Species(label="S(779)", molecule=[Molecule(smiles="[O-][NH2+]ON=O")], molecular_weight=(78.0276,'amu'))),
#              ('S(5729)',
#               Species(label="S(5729)", molecule=[Molecule(smiles="O=NON=C([O])[O]")], molecular_weight=(104.022,'amu'))),
#              ('CH3OX(429)',
#               Species(label="CH3OX(429)", molecule=[Molecule(smiles="OC[Pt]")], molecular_weight=(31.0339,'amu'))),
#              ('SX(4090)',
#               Species(label="SX(4090)", molecule=[Molecule(smiles="[O-][N+](=O)C(=O)[Pt]")], molecular_weight=(74.0156,'amu'))),
#              ('H2X(432)',
#               Species(label="H2X(432)", molecule=[Molecule(smiles="[H][H].[Pt]")], molecular_weight=(2.01588,'amu'))),
#              ('HNOX(1864)',
#               Species(label="HNOX(1864)", molecule=[Molecule(smiles="[O-][NH+]=[Pt]")], molecular_weight=(31.0141,'amu'))),
#              ('HNO2(362)',
#               Species(label="HNO2(362)", molecule=[Molecule(smiles="O[N][O]")], molecular_weight=(47.0135,'amu'))),
#              ('SX(7973)',
#               Species(label="SX(7973)", molecule=[Molecule(smiles="OC=[Pt]")], molecular_weight=(30.026,'amu'))),
#              ('CHOX(4093)',
#               Species(label="CHOX(4093)", molecule=[Molecule(smiles="OC#[Pt]")], molecular_weight=(29.018,'amu'))),
#              ('C2H4(209)',
#               Species(label="C2H4(209)", molecule=[Molecule(smiles="[CH]C")], molecular_weight=(28.0532,'amu'))),
#              ('S(1931)',
#               Species(label="S(1931)", molecule=[Molecule(smiles="OC=[N]")], molecular_weight=(44.0327,'amu'))),
#              ('CHNO(9405)',
#               Species(label="CHNO(9405)", molecule=[Molecule(smiles="[O]C=[N]")], molecular_weight=(43.0248,'amu'))),
#              ('CX(42)',
#               Species(label="CX(42)", molecule=[Molecule(smiles="C~[Pt]")], molecular_weight=(12.0107,'amu'))),
#              ('CHX(44)',
#               Species(label="CHX(44)", molecule=[Molecule(smiles="C#[Pt]")], molecular_weight=(13.0186,'amu'))),
#              ('CH3X(39)',
#               Species(label="CH3X(39)", molecule=[Molecule(smiles="C[Pt]")], molecular_weight=(15.0345,'amu'))),
#              ('CO2X(40)',
#               Species(label="CO2X(40)", molecule=[Molecule(smiles="O=C=O.[Pt]")], molecular_weight=(44.0095,'amu'))),
#              ('CH2X(43)',
#               Species(label="CH2X(43)", molecule=[Molecule(smiles="C=[Pt]")], molecular_weight=(14.0266,'amu'))),
#              ('O(45)',
#               Species(label="O(45)", molecule=[Molecule(smiles="[O]")], molecular_weight=(15.9994,'amu'))),
#              ('HOCO(50)',
#               Species(label="HOCO(50)", molecule=[Molecule(smiles="O=[C]O")], molecular_weight=(45.0174,'amu'))),
#              ('HO2(48)',
#               Species(label="HO2(48)", molecule=[Molecule(smiles="[O]O")], molecular_weight=(33.0067,'amu'))),
#              ('H2O2(49)',
#               Species(label="H2O2(49)", molecule=[Molecule(smiles="OO")], molecular_weight=(34.0147,'amu'))),
#              ('CH2(51)',
#               Species(label="CH2(51)", molecule=[Molecule(smiles="[CH2]")], molecular_weight=(14.0266,'amu'))),
#              ('CH2(S)(52)',
#               Species(label="CH2(S)(52)", molecule=[Molecule(smiles="[CH2]")], molecular_weight=(14.0266,'amu'))),
#              ('CH(53)',
#               Species(label="CH(53)", molecule=[Molecule(smiles="[CH]")], molecular_weight=(13.0186,'amu'))),
#              ('HCOH(56)',
#               Species(label="HCOH(56)", molecule=[Molecule(smiles="[C-]=[OH+]")], molecular_weight=(30.026,'amu'))),
#              ('CH3OO(57)',
#               Species(label="CH3OO(57)", molecule=[Molecule(smiles="CO[O]")], molecular_weight=(47.0333,'amu'))),
#              ('CH2CO(58)',
#               Species(label="CH2CO(58)", molecule=[Molecule(smiles="C=C=O")], molecular_weight=(42.0367,'amu'))),
#              ('C2H3(59)',
#               Species(label="C2H3(59)", molecule=[Molecule(smiles="[CH]=C")], molecular_weight=(27.0452,'amu'))),
#              ('C(60)',
#               Species(label="C(60)", molecule=[Molecule(smiles="[C]")], molecular_weight=(12.0107,'amu'))),
#              ('C2H2(61)',
#               Species(label="C2H2(61)", molecule=[Molecule(smiles="C#C")], molecular_weight=(26.0373,'amu'))),
#              ('C2H(62)',
#               Species(label="C2H(62)", molecule=[Molecule(smiles="[C]#C")], molecular_weight=(25.0293,'amu'))),
#              ('Ar(46)',
#               Species(label="Ar(46)", molecule=[Molecule(smiles="[Ar]")], molecular_weight=(39.348,'amu'))),
#              ('CH3OOH(63)',
#               Species(label="CH3OOH(63)", molecule=[Molecule(smiles="COO")], molecular_weight=(48.0413,'amu'))),
#              ('CH2OOH(64)',
#               Species(label="CH2OOH(64)", molecule=[Molecule(smiles="[CH2]OO")], molecular_weight=(47.0333,'amu'))),
#              ('HOCH2O(65)',
#               Species(label="HOCH2O(65)", molecule=[Molecule(smiles="[O]CO")], molecular_weight=(47.0333,'amu'))),
#              ('HOCHO(66)',
#               Species(label="HOCHO(66)", molecule=[Molecule(smiles="O=CO")], molecular_weight=(46.0254,'amu'))),
#              ('C2H5O(67)',
#               Species(label="C2H5O(67)", molecule=[Molecule(smiles="CC[O]")], molecular_weight=(45.0605,'amu'))),
#              ('C2H5O2(68)',
#               Species(label="C2H5O2(68)", molecule=[Molecule(smiles="CCO[O]")], molecular_weight=(61.0599,'amu'))),
#              ('C2H5O2(69)',
#               Species(label="C2H5O2(69)", molecule=[Molecule(smiles="[CH2]COO")], molecular_weight=(61.0599,'amu'))),
#              ('cC2H4O(70)',
#               Species(label="cC2H4O(70)", molecule=[Molecule(smiles="C1CO1")], molecular_weight=(44.0526,'amu'))),
#              ('CH2CHO(71)',
#               Species(label="CH2CHO(71)", molecule=[Molecule(smiles="[CH2]C=O")], molecular_weight=(43.0446,'amu'))),
#              ('H2CC(72)',
#               Species(label="H2CC(72)", molecule=[Molecule(smiles="[C]=C")], molecular_weight=(26.0373,'amu'))),
#              ('CH3CO(73)',
#               Species(label="CH3CO(73)", molecule=[Molecule(smiles="C[C]=O")], molecular_weight=(43.0446,'amu'))),
#              ('C2H4O(74)',
#               Species(label="C2H4O(74)", molecule=[Molecule(smiles="C=CO")], molecular_weight=(44.0526,'amu'))),
#              ('C2H5O(75)',
#               Species(label="C2H5O(75)", molecule=[Molecule(smiles="[CH2]CO")], molecular_weight=(45.0605,'amu'))),
#              ('C2H3O2(76)',
#               Species(label="C2H3O2(76)", molecule=[Molecule(smiles="C=CO[O]")], molecular_weight=(59.044,'amu'))),
#              ('CHCHO(77)',
#               Species(label="CHCHO(77)", molecule=[Molecule(smiles="[CH]=C[O]")], molecular_weight=(42.0367,'amu'))),
#              ('OCHCHO(78)',
#               Species(label="OCHCHO(78)", molecule=[Molecule(smiles="O=CC=O")], molecular_weight=(58.0361,'amu'))),
#              ('HCCO(79)',
#               Species(label="HCCO(79)", molecule=[Molecule(smiles="[CH]=C=O")], molecular_weight=(41.0287,'amu'))),
#              ('HCCOH(80)',
#               Species(label="HCCOH(80)", molecule=[Molecule(smiles="C#CO")], molecular_weight=(42.0367,'amu'))),
#              ('CHCHOH(81)',
#               Species(label="CHCHOH(81)", molecule=[Molecule(smiles="[CH]=CO")], molecular_weight=(43.0446,'amu'))),
#              ('C2(82)',
#               Species(label="C2(82)", molecule=[Molecule(smiles="[C]#[C]")], molecular_weight=(24.0214,'amu'))),
#              ('C2O(83)',
#               Species(label="C2O(83)", molecule=[Molecule(smiles="[C]=C=O")], molecular_weight=(40.0208,'amu'))),
#              ('C2H6O(84)',
#               Species(label="C2H6O(84)", molecule=[Molecule(smiles="CCO")], molecular_weight=(46.0684,'amu'))),
#              ('C2H5O(85)',
#               Species(label="C2H5O(85)", molecule=[Molecule(smiles="C[CH]O")], molecular_weight=(45.0605,'amu'))),
#              ('C2H5O3(86)',
#               Species(label="C2H5O3(86)", molecule=[Molecule(smiles="[O]OCCO")], molecular_weight=(77.0593,'amu'))),
#              ('cC2H3O(87)',
#               Species(label="cC2H3O(87)", molecule=[Molecule(smiles="[CH]1CO1")], molecular_weight=(43.0446,'amu'))),
#              ('C2H3O3(88)',
#               Species(label="C2H3O3(88)", molecule=[Molecule(smiles="CC(=O)O[O]")], molecular_weight=(75.0434,'amu'))),
#              ('OCHCO(89)',
#               Species(label="OCHCO(89)", molecule=[Molecule(smiles="O=[C]C=O")], molecular_weight=(57.0281,'amu'))),
#              ('C2H6O2(90)',
#               Species(label="C2H6O2(90)", molecule=[Molecule(smiles="CCOO")], molecular_weight=(62.0678,'amu'))),
#              ('C2H5O2(91)',
#               Species(label="C2H5O2(91)", molecule=[Molecule(smiles="C[CH]OO")], molecular_weight=(61.0599,'amu'))),
#              ('C2H4O2(92)',
#               Species(label="C2H4O2(92)", molecule=[Molecule(smiles="C=COO")], molecular_weight=(60.052,'amu'))),
#              ('OCHO(93)',
#               Species(label="OCHO(93)", molecule=[Molecule(smiles="[O]C=O")], molecular_weight=(45.0174,'amu'))),
#              ('NH(95)',
#               Species(label="NH(95)", molecule=[Molecule(smiles="[NH]")], molecular_weight=(15.0147,'amu'))),
#              ('HON(98)',
#               Species(label="HON(98)", molecule=[Molecule(smiles="[N-]=[OH+]")], molecular_weight=(31.0141,'amu'))),
#              ('N(99)',
#               Species(label="N(99)", molecule=[Molecule(smiles="[N]")], molecular_weight=(14.0067,'amu'))),
#              ('NNH(100)',
#               Species(label="NNH(100)", molecule=[Molecule(smiles="N=[N]")], molecular_weight=(29.0214,'amu'))),
#              ('N2H2(104)',
#               Species(label="N2H2(104)", molecule=[Molecule(smiles="N=N")], molecular_weight=(30.0294,'amu'))),
#              ('H2N2(105)',
#               Species(label="H2N2(105)", molecule=[Molecule(smiles="[N-]=[NH2+]")], molecular_weight=(30.0294,'amu'))),
#              ('N2H3(106)',
#               Species(label="N2H3(106)", molecule=[Molecule(smiles="N[NH]")], molecular_weight=(31.0373,'amu'))),
#              ('N2H4(107)',
#               Species(label="N2H4(107)", molecule=[Molecule(smiles="NN")], molecular_weight=(32.0452,'amu'))),
#              ('HCN(108)',
#               Species(label="HCN(108)", molecule=[Molecule(smiles="C#N")], molecular_weight=(27.0254,'amu'))),
#              ('CN(109)',
#               Species(label="CN(109)", molecule=[Molecule(smiles="[C]#N")], molecular_weight=(26.0174,'amu'))),
#              ('HNC(110)',
#               Species(label="HNC(110)", molecule=[Molecule(smiles="[C-]#[NH+]")], molecular_weight=(27.0254,'amu'))),
#              ('NCO(111)',
#               Species(label="NCO(111)", molecule=[Molecule(smiles="[O]C#N")], molecular_weight=(42.0168,'amu'))),
#              ('HOCN(112)',
#               Species(label="HOCN(112)", molecule=[Molecule(smiles="OC#N")], molecular_weight=(43.0248,'amu'))),
#              ('HNCO(113)',
#               Species(label="HNCO(113)", molecule=[Molecule(smiles="N=C=O")], molecular_weight=(43.0248,'amu'))),
#              ('NCCN(114)',
#               Species(label="NCCN(114)", molecule=[Molecule(smiles="[N]=[C]C#N")], molecular_weight=(52.0349,'amu'))),
#              ('HNCN(115)',
#               Species(label="HNCN(115)", molecule=[Molecule(smiles="N=C=[N]")], molecular_weight=(41.0321,'amu'))),
#              ('NCN(116)',
#               Species(label="NCN(116)", molecule=[Molecule(smiles="[N]=C=[N]")], molecular_weight=(40.0242,'amu'))),
#              ('HNCNH(117)',
#               Species(label="HNCNH(117)", molecule=[Molecule(smiles="N=C=N")], molecular_weight=(42.0401,'amu'))),
#              ('HCNO(118)',
#               Species(label="HCNO(118)", molecule=[Molecule(smiles="[O-][N+]#C")], molecular_weight=(43.0248,'amu'))),
#              ('CH3CN(119)',
#               Species(label="CH3CN(119)", molecule=[Molecule(smiles="CC#N")], molecular_weight=(41.052,'amu'))),
#              ('CH2CN(120)',
#               Species(label="CH2CN(120)", molecule=[Molecule(smiles="C=C=[N]")], molecular_weight=(40.044,'amu'))),
#              ('CH2NH(121)',
#               Species(label="CH2NH(121)", molecule=[Molecule(smiles="C=N")], molecular_weight=(29.0413,'amu'))),
#              ('H2CN(122)',
#               Species(label="H2CN(122)", molecule=[Molecule(smiles="C=[N]")], molecular_weight=(28.0333,'amu'))),
#              ('CH3NO(123)',
#               Species(label="CH3NO(123)", molecule=[Molecule(smiles="CN=O")], molecular_weight=(45.0407,'amu'))),
#              ('CH4N(124)',
#               Species(label="CH4N(124)", molecule=[Molecule(smiles="[CH2]N")], molecular_weight=(30.0492,'amu'))),
#              ('NCNOH(125)',
#               Species(label="NCNOH(125)", molecule=[Molecule(smiles="O[N]C#N")], molecular_weight=(57.0315,'amu'))),
#              ('NCNO(126)',
#               Species(label="NCNO(126)", molecule=[Molecule(smiles="O=NC#N")], molecular_weight=(56.0236,'amu'))),
#              ('CH2NO(127)',
#               Species(label="CH2NO(127)", molecule=[Molecule(smiles="[CH2]N=O")], molecular_weight=(44.0327,'amu'))),
#              ('S(128)',
#               Species(label="S(128)", molecule=[Molecule(smiles="CCN=O")], molecular_weight=(59.0672,'amu'))),
#              ('S(129)',
#               Species(label="S(129)", molecule=[Molecule(smiles="CC=N[O]")], molecular_weight=(58.0593,'amu'))),
#              ('S(130)',
#               Species(label="S(130)", molecule=[Molecule(smiles="C=CN=O")], molecular_weight=(57.0514,'amu'))),
#              ('S(131)',
#               Species(label="S(131)", molecule=[Molecule(smiles="[CH]=CN=O")], molecular_weight=(56.0434,'amu'))),
#              ('S(132)',
#               Species(label="S(132)", molecule=[Molecule(smiles="[O-][N+](=O)C")], molecular_weight=(61.0401,'amu'))),
#              ('S(133)',
#               Species(label="S(133)", molecule=[Molecule(smiles="[O-][N+](=O)[CH2]")], molecular_weight=(60.0321,'amu'))),
#              ('S(134)',
#               Species(label="S(134)", molecule=[Molecule(smiles="[O-][N+](=O)CC")], molecular_weight=(75.0666,'amu'))),
#              ('S(135)',
#               Species(label="S(135)", molecule=[Molecule(smiles="CCON=O")], molecular_weight=(75.0666,'amu'))),
#              ('S(136)',
#               Species(label="S(136)", molecule=[Molecule(smiles="[O-][N+](=O)C[CH2]")], molecular_weight=(74.0587,'amu'))),
#              ('S(137)',
#               Species(label="S(137)", molecule=[Molecule(smiles="[O-][N+](=O)[CH]C")], molecular_weight=(74.0587,'amu'))),
#              ('S(138)',
#               Species(label="S(138)", molecule=[Molecule(smiles="CON=O")], molecular_weight=(61.0401,'amu'))),
#              ('S(139)',
#               Species(label="S(139)", molecule=[Molecule(smiles="[O-][N+](=O)OC")], molecular_weight=(77.0395,'amu'))),
#              ('S(140)',
#               Species(label="S(140)", molecule=[Molecule(smiles="[O-][N+](=O)OCC")], molecular_weight=(91.066,'amu'))),
#              ('CH5N(141)',
#               Species(label="CH5N(141)", molecule=[Molecule(smiles="CN")], molecular_weight=(31.0571,'amu'))),
#              ('CH3NH(142)',
#               Species(label="CH3NH(142)", molecule=[Molecule(smiles="C[NH]")], molecular_weight=(30.0492,'amu'))),
#              ('HCNH(143)',
#               Species(label="HCNH(143)", molecule=[Molecule(smiles="[CH]=N")], molecular_weight=(28.0333,'amu'))),
#              ('C2H7N(144)',
#               Species(label="C2H7N(144)", molecule=[Molecule(smiles="CCN")], molecular_weight=(45.0837,'amu'))),
#              ('C2H6N(145)',
#               Species(label="C2H6N(145)", molecule=[Molecule(smiles="C[CH]N")], molecular_weight=(44.0758,'amu'))),
#              ('C2H6N(146)',
#               Species(label="C2H6N(146)", molecule=[Molecule(smiles="[CH2]CN")], molecular_weight=(44.0758,'amu'))),
#              ('C2H6N(147)',
#               Species(label="C2H6N(147)", molecule=[Molecule(smiles="CC[NH]")], molecular_weight=(44.0758,'amu'))),
#              ('C2H5N(148)',
#               Species(label="C2H5N(148)", molecule=[Molecule(smiles="NC=C")], molecular_weight=(43.0678,'amu'))),
#              ('C2H5N(149)',
#               Species(label="C2H5N(149)", molecule=[Molecule(smiles="CC=N")], molecular_weight=(43.0678,'amu'))),
#              ('CH3NO(150)',
#               Species(label="CH3NO(150)", molecule=[Molecule(smiles="NC=O")], molecular_weight=(45.0407,'amu'))),
#              ('C2H4N(151)',
#               Species(label="C2H4N(151)", molecule=[Molecule(smiles="NC=[CH]")], molecular_weight=(42.0599,'amu'))),
#              ('C2H4N(152)',
#               Species(label="C2H4N(152)", molecule=[Molecule(smiles="N[C]=C")], molecular_weight=(42.0599,'amu'))),
#              ('C2H4N(153)',
#               Species(label="C2H4N(153)", molecule=[Molecule(smiles="[CH2]C=N")], molecular_weight=(42.0599,'amu'))),
#              ('H2NCO(154)',
#               Species(label="H2NCO(154)", molecule=[Molecule(smiles="N[C]=O")], molecular_weight=(44.0327,'amu'))),
#              ('C2H4N(155)',
#               Species(label="C2H4N(155)", molecule=[Molecule(smiles="C[C]=N")], molecular_weight=(42.0599,'amu'))),
#              ('C2H4N(156)',
#               Species(label="C2H4N(156)", molecule=[Molecule(smiles="CC=[N]")], molecular_weight=(42.0599,'amu'))),
#              ('C2H3N(157)',
#               Species(label="C2H3N(157)", molecule=[Molecule(smiles="NC#C")], molecular_weight=(41.052,'amu'))),
#              ('C2H3N(158)',
#               Species(label="C2H3N(158)", molecule=[Molecule(smiles="C=C=N")], molecular_weight=(41.052,'amu'))),
#              ('C2H3N(159)',
#               Species(label="C2H3N(159)", molecule=[Molecule(smiles="[CH2]C=[N]")], molecular_weight=(41.052,'amu'))),
#              ('C2H3N(160)',
#               Species(label="C2H3N(160)", molecule=[Molecule(smiles="[N]C=C")], molecular_weight=(41.052,'amu'))),
#              ('CHCNH(161)',
#               Species(label="CHCNH(161)", molecule=[Molecule(smiles="[NH]C#C")], molecular_weight=(40.044,'amu'))),
#              ('C2H3N(162)',
#               Species(label="C2H3N(162)", molecule=[Molecule(smiles="C1C=N1")], molecular_weight=(41.052,'amu'))),
#              ('C2H4N(163)',
#               Species(label="C2H4N(163)", molecule=[Molecule(smiles="[CH2]N=C")], molecular_weight=(42.0599,'amu'))),
#              ('C2H6N(164)',
#               Species(label="C2H6N(164)", molecule=[Molecule(smiles="CN[CH2]")], molecular_weight=(44.0758,'amu'))),
#              ('C2H7N(165)',
#               Species(label="C2H7N(165)", molecule=[Molecule(smiles="CNC")], molecular_weight=(45.0837,'amu'))),
#              ('C2H6N(166)',
#               Species(label="C2H6N(166)", molecule=[Molecule(smiles="C[N]C")], molecular_weight=(44.0758,'amu'))),
#              ('C2H5N(167)',
#               Species(label="C2H5N(167)", molecule=[Molecule(smiles="CN=C")], molecular_weight=(43.0678,'amu'))),
#              ('C2H4N(168)',
#               Species(label="C2H4N(168)", molecule=[Molecule(smiles="CN=[CH]")], molecular_weight=(42.0599,'amu')))])
